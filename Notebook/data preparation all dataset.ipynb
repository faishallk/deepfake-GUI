# %% [markdown]
# # Data Preparation (After Cropped Face Data)

# %% [markdown]
# ## Statistics Preprocessed Data

# %%
import os
import cv2
import shutil

# %%
def calculate_video_statistics(video_folder):
    total_frame_count = 0
    total_video_length = 0
    total_video_count = 0

    for root, dirs, files in os.walk(video_folder):
        for file in files:
            if file.endswith(".mp4"):  # Assuming all video files are in mp4 format
                video_path = os.path.join(root, file)
                cap = cv2.VideoCapture(video_path)
                frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
                fps = int(cap.get(cv2.CAP_PROP_FPS))

                # Ensure FPS is not zero to avoid division by zero error
                if fps != 0:
                    video_length = frame_count / fps
                    total_frame_count += frame_count
                    total_video_length += video_length
                    total_video_count += 1
                cap.release()

    # Calculate average frames per video
    average_frame_per_video = total_frame_count / total_video_count if total_video_count != 0 else 0
    # Calculate average video length per video
    average_video_length_per_video = total_video_length / total_video_count if total_video_count != 0 else 0
    
    return total_frame_count, total_video_length, average_frame_per_video, average_video_length_per_video

def merge_video_folders(destination_folder, *folders):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    all_files = []
    for folder in folders:
        for root, dirs, files in os.walk(folder):
            for file in files:
                if file.endswith(".mp4"):
                    source_file = os.path.join(root, file)
                    destination_file = os.path.join(destination_folder, file)
                    if not os.path.exists(destination_file):
                        shutil.copy2(source_file, destination_file)
                    all_files.append(destination_file)
    return all_files

def calculate_statistics_from_file_list(file_list):
    total_frame_count = 0
    total_video_length = 0
    total_video_count = 0

    for video_path in file_list:
        cap = cv2.VideoCapture(video_path)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))

        # Ensure FPS is not zero to avoid division by zero error
        if fps != 0:
            video_length = frame_count / fps
            total_frame_count += frame_count
            total_video_length += video_length
            total_video_count += 1
        cap.release()

    # Calculate average frames per video
    average_frame_per_video = total_frame_count / total_video_count if total_video_count != 0 else 0
    # Calculate average video length per video
    average_video_length_per_video = total_video_length / total_video_count if total_video_count != 0 else 0
    
    return total_frame_count, total_video_length, average_frame_per_video, average_video_length_per_video

# %%
# Define file paths
celebdf_fake_processed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf fake'
celebdf_real_processed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real'
ff_real_processed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real'
ff_fake_processed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake'

# Calculate statistics for each folder
celebdf_fake_processed_stats = calculate_video_statistics(celebdf_fake_processed_data)
celebdf_real_processed_stats = calculate_video_statistics(celebdf_real_processed_data)
ff_real_processed_stats = calculate_video_statistics(ff_real_processed_data)
ff_fake_processed_stats = calculate_video_statistics(ff_fake_processed_data)
# Out:
# OpenCV: Couldn't read video stream from file "/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real/id27_0005_faces.mp4"
# OpenCV: Couldn't read video stream from file "/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__walking_down_street_outside_angry_faces.mp4"

# %% [markdown]
# ## general stats for original data

# %%
print("FaceForensics++ Fake Data:")
print("Total Frame Count:", ff_fake_processed_stats[0])
print("Total Video Length (seconds):", ff_fake_processed_stats[1])
print("Average Frames per Video:", ff_fake_processed_stats[2])
print("Average Video Length per Video (seconds):", ff_fake_processed_stats[3])
print()
# Out:
# FaceForensics++ Fake Data:
# Total Frame Count: 52216
# Total Video Length (seconds): 1740.533333333336
# Average Frames per Video: 143.45054945054946
# Average Video Length per Video (seconds): 4.781684981684989

# %%
print("FaceForensics++ Real Data:")
print("Total Frame Count:", ff_real_processed_stats[0])
print("Total Video Length (seconds):", ff_real_processed_stats[1])
print("Average Frames per Video:", ff_real_processed_stats[2])
print("Average Video Length per Video (seconds):", ff_real_processed_stats[3])
print()
# Out:
# FaceForensics++ Real Data:
# Total Frame Count: 48944
# Total Video Length (seconds): 1631.466666666667
# Average Frames per Video: 135.20441988950276
# Average Video Length per Video (seconds): 4.506813996316759

# %%
print("Celeb-DF Fake Data:")
print("Total Frame Count:", celebdf_fake_processed_stats[0])
print("Total Video Length (seconds):", celebdf_fake_processed_stats[1])
print("Average Frames per Video:", celebdf_fake_processed_stats[2])
print("Average Video Length per Video (seconds):", celebdf_fake_processed_stats[3])
print()
# Out:
# Celeb-DF Fake Data:
# Total Frame Count: 87256
# Total Video Length (seconds): 2908.5333333333506
# Average Frames per Video: 147.8915254237288
# Average Video Length per Video (seconds): 4.929717514124323

# %%
print("Celeb-DF real Data:")
print("Total Frame Count:", celebdf_real_processed_stats[0])
print("Total Video Length (seconds):", celebdf_real_processed_stats[1])
print("Average Frames per Video:", celebdf_real_processed_stats[2])
print("Average Video Length per Video (seconds):", celebdf_real_processed_stats[3])
print()
# Out:
# Celeb-DF real Data:
# Total Frame Count: 86580
# Total Video Length (seconds): 2886.0000000000177
# Average Frames per Video: 146.9949066213922
# Average Video Length per Video (seconds): 4.8998302207131035

# %% [markdown]
# ## transformed data stats (generated after process of extract from transformed is done)

# %%
import os
import cv2
import shutil

# Base directory where the extracted frames are stored
extracted_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames/transformed'

# Define paths for the datasets
datasets = {
    'celebdf_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/celebdf_real',
    'celebdf_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/celebdf_fake',
    'ff_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/ff_real',
    'ff_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/ff_fake'
}

def calculate_video_statistics(video_folder):
    total_frame_count = 0
    total_video_length = 0
    total_video_count = 0

    for root, dirs, files in os.walk(video_folder):
        for file in files:
            if file.endswith(".mp4"):  # Assuming all video files are in mp4 format
                video_path = os.path.join(root, file)
                cap = cv2.VideoCapture(video_path)
                frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
                fps = int(cap.get(cv2.CAP_PROP_FPS))

                # Ensure FPS is not zero to avoid division by zero error
                if fps != 0:
                    video_length = frame_count / fps
                    total_frame_count += frame_count
                    total_video_length += video_length
                    total_video_count += 1
                cap.release()

    # Calculate average frames per video
    average_frame_per_video = total_frame_count / total_video_count if total_video_count != 0 else 0
    # Calculate average video length per video
    average_video_length_per_video = total_video_length / total_video_count if total_video_count != 0 else 0
    
    return total_frame_count, total_video_length, average_frame_per_video, average_video_length_per_video

def merge_video_folders(destination_folder, *folders):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    all_files = []
    for folder in folders:
        for root, dirs, files in os.walk(folder):
            for file in files:
                if file.endswith(".mp4"):
                    source_file = os.path.join(root, file)
                    destination_file = os.path.join(destination_folder, file)
                    if not os.path.exists(destination_file):
                        shutil.copy2(source_file, destination_file)
                    all_files.append(destination_file)
    return all_files

def calculate_statistics_from_file_list(file_list):
    total_frame_count = 0
    total_video_length = 0
    total_video_count = 0

    for video_path in file_list:
        cap = cv2.VideoCapture(video_path)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))

        # Ensure FPS is not zero to avoid division by zero error
        if fps != 0:
            video_length = frame_count / fps
            total_frame_count += frame_count
            total_video_length += video_length
            total_video_count += 1
        cap.release()

    # Calculate average frames per video
    average_frame_per_video = total_frame_count / total_video_count if total_video_count != 0 else 0
    # Calculate average video length per video
    average_video_length_per_video = total_video_length / total_video_count if total_video_count != 0 else 0
    
    return total_frame_count, total_video_length, average_frame_per_video, average_video_length_per_video

# %%
# Define file paths based on the transformed datasets
celebdf_fake_transformed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/celebdf_fake'
celebdf_real_transformed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/celebdf_real'
ff_real_transformed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/ff_real'
ff_fake_transformed_data = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/ff_fake'

# Calculate statistics for each folder
celebdf_fake_transformed_stats = calculate_video_statistics(celebdf_fake_transformed_data)
celebdf_real_transformed_stats = calculate_video_statistics(celebdf_real_transformed_data)
ff_real_transformed_stats = calculate_video_statistics(ff_real_transformed_data)
ff_fake_transformed_stats = calculate_video_statistics(ff_fake_transformed_data)

# %%
print("FaceForensics++ Fake Data Transformed:")
print("Total Frame Count:", ff_fake_transformed_stats[0])
print("Total Video Length (seconds):", ff_fake_transformed_stats[1])
print("Average Frames per Video:", ff_fake_transformed_stats[2])
print("Average Video Length per Video (seconds):", ff_fake_transformed_stats[3])
print()
# Out:
# FaceForensics++ Fake Data Transformed:
# Total Frame Count: 0
# Total Video Length (seconds): 0
# Average Frames per Video: 0
# Average Video Length per Video (seconds): 0

# %% [markdown]
# ## Extract the frames for all dataset (faceforensics++ and celebdf (both of real and fake data))

# %% [markdown]
# ## not used

# %%
import os
import cv2
from torch.utils.data import Dataset

# %%
# Set the main directory path for extracted frames
extracted_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames'

# Create the directory if it doesn't exist
if not os.path.exists(extracted_frames_main_dir):
    os.makedirs(extracted_frames_main_dir)

# Custom dataset class to load videos and extract frames
class VideoDataset(Dataset):
    def __init__(self, video_dir, output_dir):
        self.video_dir = video_dir
        self.output_dir = output_dir
        self.video_files = [os.path.join(video_dir, f) for f in os.listdir(video_dir) if f.endswith('.mp4')]
        self.valid_video_files = self._filter_valid_videos()

    def _filter_valid_videos(self):
        valid_videos = []
        for video_path in self.video_files:
            cap = cv2.VideoCapture(video_path)
            valid = False
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                valid = True
                break
            cap.release()
            if valid:
                valid_videos.append(video_path)
            else:
                print(f"No frames extracted from video: {video_path}")
        return valid_videos

    def __len__(self):
        return len(self.valid_video_files)

    def __getitem__(self, idx):
        video_path = self.valid_video_files[idx]
        cap = cv2.VideoCapture(video_path)
        frames = []
        label = 1 if 'fake' in video_path else 0  # Assuming you determine labels based on file path

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            frames.append(frame)
        cap.release()

        if len(frames) == 0:
            raise RuntimeError(f"No frames extracted from video: {video_path}")

        # Pad or truncate to max_frames
        if len(frames) < self.max_frames:
            pad_size = self.max_frames - len(frames)
            frames.extend([torch.zeros_like(frames[0])] * pad_size)
        elif len(frames) > self.max_frames:
            frames = frames[:self.max_frames]

        return frames, label  # Only return frames and label

    def extract_frames(self):
        """
        Extracts frames from each video and saves them in a structured directory.
        """
        for video_path in self.valid_video_files:
            cap = cv2.VideoCapture(video_path)
            video_name = os.path.splitext(os.path.basename(video_path))[0]

            # Define the output directory for this video's frames
            video_output_dir = os.path.join(self.output_dir, video_name)
            os.makedirs(video_output_dir, exist_ok=True)

            frame_count = 0
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                # Save each frame as a .jpg file
                frame_filename = os.path.join(video_output_dir, f'frame_{frame_count:04d}.jpg')
                cv2.imwrite(frame_filename, frame)
                frame_count += 1

            cap.release()
            print(f"Extracted {frame_count} frames from video: {video_name}")

# %%
# Define paths for the datasets
datasets = {
    'celebdf_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real',
    'celebdf_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf fake',
    'ff_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real',
    'ff_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake'
}

# %%
# Extract frames for each dataset
for dataset_name, dataset_path in datasets.items():
    print(f"Processing dataset: {dataset_name}")

    # Define the output directory for extracted frames for this dataset
    output_dir = os.path.join(extracted_frames_main_dir, dataset_name)
    os.makedirs(output_dir, exist_ok=True)

    # Create a VideoDataset instance for this dataset
    video_dataset = VideoDataset(video_dir=dataset_path, output_dir=output_dir)

    # Extract frames for all videos in the dataset
    video_dataset.extract_frames()
# Out:
# Processing dataset: celebdf_real
# No frames extracted from video: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real/id27_0005_faces.mp4
# OpenCV: Couldn't read video stream from file "/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real/id27_0005_faces.mp4"
# Extracted 148 frames from video: id6_0003_faces
# Extracted 148 frames from video: id7_0008_faces
# Extracted 148 frames from video: id46_0002_faces
# Extracted 148 frames from video: id53_0002_faces
# Extracted 148 frames from video: id17_0001_faces
# Extracted 148 frames from video: id52_0009_faces
# Extracted 148 frames from video: id47_0009_faces
# Extracted 148 frames from video: id28_0008_faces
# Extracted 148 frames from video: id0_0005_faces
# Extracted 148 frames from video: id29_0003_faces
# Extracted 148 frames from video: id11_0007_faces
# Extracted 148 frames from video: id40_0004_faces
# Extracted 148 frames from video: id55_0004_faces
# Extracted 148 frames from video: id22_0002_faces
# Extracted 148 frames from video: id37_0002_faces
# Extracted 148 frames from video: id36_0009_faces
# Extracted 148 frames from video: id23_0009_faces
# Extracted 148 frames from video: id59_0008_faces
# Extracted 148 frames from video: id58_0003_faces
# Extracted 148 frames from video: id60_0007_faces
# Extracted 148 frames from video: id24_0004_faces
# Extracted 148 frames from video: id31_0004_faces
# Extracted 148 frames from video: id39_0004_faces
# Extracted 148 frames from video: id5_0002_faces
# Extracted 148 frames from video: id4_0009_faces
# Extracted 148 frames from video: id50_0003_faces
# Extracted 148 frames from video: id45_0003_faces
# Extracted 148 frames from video: id51_0008_faces
# Extracted 148 frames from video: id3_0004_faces
# Extracted 148 frames from video: id12_0006_faces
# Extracted 148 frames from video: id56_0005_faces
# Extracted 148 frames from video: id43_0005_faces
# Extracted 148 frames from video: id48_0004_faces
# Extracted 148 frames from video: id19_0007_faces
# Extracted 148 frames from video: id8_0005_faces
# Extracted 148 frames from video: id34_0003_faces
# Extracted 124 frames from video: id21_0003_faces
# Extracted 148 frames from video: id20_0008_faces
# Extracted 148 frames from video: id35_0008_faces
# Extracted 148 frames from video: id32_0005_faces
# Extracted 148 frames from video: id52_0004_faces
# Extracted 148 frames from video: id47_0004_faces
# Extracted 148 frames from video: id16_0007_faces
# Extracted 148 frames from video: id7_0005_faces
# Extracted 148 frames from video: id40_0009_faces
# Extracted 148 frames from video: id55_0009_faces
# Extracted 76 frames from video: id10_0001_faces
# Extracted 148 frames from video: id54_0002_faces
# Extracted 148 frames from video: id41_0002_faces
# Extracted 148 frames from video: id0_0008_faces
# Extracted 148 frames from video: id1_0003_faces
# Extracted 148 frames from video: id28_0005_faces
# Extracted 148 frames from video: id36_0004_faces
# Extracted 148 frames from video: id23_0004_faces
# Extracted 148 frames from video: id24_0009_faces
# Extracted 148 frames from video: id31_0009_faces
# Extracted 8 frames from video: id61_0001_faces
# Extracted 148 frames from video: id30_0002_faces
# Extracted 148 frames from video: id25_0002_faces
# Extracted 148 frames from video: id16_0013_faces
# Extracted 148 frames from video: id59_0005_faces
# Extracted 148 frames from video: id44_0005_faces
# Extracted 148 frames from video: id51_0005_faces
# Extracted 148 frames from video: id38_0002_faces
# Extracted 148 frames from video: id4_0004_faces
# Extracted 148 frames from video: id39_0009_faces
# Extracted 148 frames from video: id56_0008_faces
# Extracted 148 frames from video: id43_0008_faces
# Extracted 148 frames from video: id13_0000_faces
# Extracted 148 frames from video: id42_0003_faces
# Extracted 148 frames from video: id57_0003_faces
# Extracted 148 frames from video: id3_0009_faces
# Extracted 148 frames from video: id2_0002_faces
# Extracted 148 frames from video: id9_0003_faces
# Extracted 148 frames from video: id20_0005_faces
# Extracted 148 frames from video: id35_0005_faces
# Extracted 148 frames from video: id8_0008_faces
# Extracted 148 frames from video: id49_0002_faces
# Extracted 148 frames from video: id48_0009_faces
# Extracted 148 frames from video: id13_0014_faces
# Extracted 148 frames from video: id32_0008_faces
# Extracted 148 frames from video: id27_0008_faces
# Extracted 148 frames from video: id26_0003_faces
# Extracted 148 frames from video: id33_0003_faces
# Extracted 148 frames from video: id3_0002_faces
# Extracted 148 frames from video: id2_0009_faces
# Extracted 148 frames from video: id56_0003_faces
# Extracted 148 frames from video: id43_0003_faces
# Extracted 148 frames from video: id12_0000_faces
# Extracted 148 frames from video: id57_0008_faces
# Extracted 148 frames from video: id38_0009_faces
# Extracted 148 frames from video: id5_0004_faces
# Extracted 148 frames from video: id39_0002_faces
# Extracted 148 frames from video: id50_0005_faces
# Extracted 148 frames from video: id45_0005_faces
# Extracted 148 frames from video: id32_0003_faces
# Extracted 148 frames from video: id27_0003_faces
# Extracted 148 frames from video: id26_0008_faces
# Extracted 148 frames from video: id33_0008_faces
# Extracted 148 frames from video: id19_0001_faces
# Extracted 148 frames from video: id49_0009_faces
# Extracted 148 frames from video: id48_0002_faces
# Extracted 148 frames from video: id9_0008_faces
# Extracted 148 frames from video: id34_0005_faces
# Extracted 148 frames from video: id21_0005_faces
# Extracted 144 frames from video: id8_0003_faces
# Extracted 148 frames from video: id29_0005_faces
# Extracted 148 frames from video: id0_0003_faces
# Extracted 112 frames from video: id1_0008_faces
# Extracted 148 frames from video: id40_0002_faces
# Extracted 148 frames from video: id55_0002_faces
# Extracted 148 frames from video: id11_0001_faces
# Extracted 148 frames from video: id54_0009_faces
# Extracted 148 frames from video: id41_0009_faces
# Extracted 148 frames from video: id6_0005_faces
# Extracted 148 frames from video: id17_0007_faces
# Extracted 148 frames from video: id46_0004_faces
# Extracted 148 frames from video: id53_0004_faces
# Extracted 148 frames from video: id58_0005_faces
# Extracted 148 frames from video: id24_0002_faces
# Extracted 148 frames from video: id31_0002_faces
# Extracted 148 frames from video: id60_0001_faces
# Extracted 148 frames from video: id30_0009_faces
# Extracted 148 frames from video: id25_0009_faces
# Extracted 148 frames from video: id22_0004_faces
# Extracted 148 frames from video: id37_0004_faces
# Extracted 148 frames from video: id57_0005_faces
# Extracted 148 frames from video: id13_0006_faces
# Extracted 148 frames from video: id2_0004_faces
# Extracted 148 frames from video: id50_0008_faces
# Extracted 148 frames from video: id45_0008_faces
# Extracted 148 frames from video: id44_0003_faces
# Extracted 148 frames from video: id51_0003_faces
# Extracted 148 frames from video: id5_0009_faces
# Extracted 148 frames from video: id4_0002_faces
# Extracted 148 frames from video: id38_0004_faces
# Extracted 148 frames from video: id26_0005_faces
# Extracted 148 frames from video: id33_0005_faces
# Extracted 148 frames from video: id34_0008_faces
# Extracted 148 frames from video: id21_0008_faces
# Extracted 148 frames from video: id20_0003_faces
# Extracted 148 frames from video: id35_0003_faces
# Extracted 148 frames from video: id9_0005_faces
# Extracted 148 frames from video: id13_0012_faces
# Extracted 148 frames from video: id49_0004_faces
# Extracted 148 frames from video: id54_0004_faces
# Extracted 148 frames from video: id41_0004_faces
# Extracted 148 frames from video: id10_0007_faces
# Extracted 148 frames from video: id28_0003_faces
# Extracted 148 frames from video: id1_0005_faces
# Extracted 148 frames from video: id29_0008_faces
# Extracted 148 frames from video: id46_0009_faces
# Extracted 148 frames from video: id53_0009_faces
# Extracted 148 frames from video: id16_0001_faces
# Extracted 148 frames from video: id52_0002_faces
# Extracted 148 frames from video: id47_0002_faces
# Extracted 148 frames from video: id6_0008_faces
# Extracted 148 frames from video: id7_0003_faces
# Extracted 148 frames from video: id25_0010_faces
# Extracted 148 frames from video: id30_0004_faces
# Extracted 148 frames from video: id25_0004_faces
# Extracted 140 frames from video: id61_0007_faces
# Extracted 148 frames from video: id59_0003_faces
# Extracted 148 frames from video: id58_0008_faces
# Extracted 148 frames from video: id22_0009_faces
# Extracted 148 frames from video: id37_0009_faces
# Extracted 148 frames from video: id36_0002_faces
# Extracted 148 frames from video: id23_0002_faces
# Extracted 148 frames from video: id36_0008_faces
# Extracted 148 frames from video: id23_0008_faces
# Extracted 148 frames from video: id22_0003_faces
# Extracted 148 frames from video: id37_0003_faces
# Extracted 148 frames from video: id58_0002_faces
# Extracted 148 frames from video: id59_0009_faces
# Extracted 148 frames from video: id24_0005_faces
# Extracted 148 frames from video: id31_0005_faces
# Extracted 104 frames from video: id60_0006_faces
# Extracted 148 frames from video: id7_0009_faces
# Extracted 148 frames from video: id6_0002_faces
# Extracted 148 frames from video: id17_0000_faces
# Extracted 148 frames from video: id52_0008_faces
# Extracted 148 frames from video: id47_0008_faces
# Extracted 148 frames from video: id46_0003_faces
# Extracted 148 frames from video: id53_0003_faces
# Extracted 148 frames from video: id29_0002_faces
# Extracted 148 frames from video: id0_0004_faces
# Extracted 148 frames from video: id28_0009_faces
# Extracted 148 frames from video: id40_0005_faces
# Extracted 148 frames from video: id55_0005_faces
# Extracted 148 frames from video: id11_0006_faces
# Extracted 148 frames from video: id19_0006_faces
# Extracted 148 frames from video: id48_0005_faces
# Extracted 148 frames from video: id20_0009_faces
# Extracted 148 frames from video: id35_0009_faces
# Extracted 148 frames from video: id34_0002_faces
# Extracted 148 frames from video: id21_0002_faces
# Extracted 148 frames from video: id8_0004_faces
# Extracted 148 frames from video: id32_0004_faces
# Extracted 148 frames from video: id27_0004_faces
# Extracted 148 frames from video: id4_0008_faces
# Extracted 148 frames from video: id5_0003_faces
# Extracted 148 frames from video: id39_0005_faces
# Extracted 148 frames from video: id51_0009_faces
# Extracted 148 frames from video: id50_0002_faces
# Extracted 148 frames from video: id45_0002_faces
# Extracted 148 frames from video: id3_0005_faces
# Extracted 148 frames from video: id56_0004_faces
# Extracted 148 frames from video: id43_0004_faces
# Extracted 148 frames from video: id36_0005_faces
# Extracted 148 frames from video: id23_0005_faces
# Extracted 148 frames from video: id30_0003_faces
# Extracted 148 frames from video: id25_0003_faces
# Extracted 148 frames from video: id24_0008_faces
# Extracted 148 frames from video: id31_0008_faces
# Extracted 148 frames from video: id61_0000_faces
# Extracted 148 frames from video: id59_0004_faces
# Extracted 148 frames from video: id16_0012_faces
# Extracted 148 frames from video: id16_0006_faces
# Extracted 148 frames from video: id52_0005_faces
# Extracted 148 frames from video: id47_0005_faces
# Extracted 148 frames from video: id7_0004_faces
# Extracted 148 frames from video: id54_0003_faces
# Extracted 148 frames from video: id41_0003_faces
# Extracted 148 frames from video: id40_0008_faces
# Extracted 148 frames from video: id55_0008_faces
# Extracted 148 frames from video: id10_0000_faces
# Extracted 148 frames from video: id28_0004_faces
# Extracted 148 frames from video: id1_0002_faces
# Extracted 148 frames from video: id0_0009_faces
# Extracted 148 frames from video: id8_0009_faces
# Extracted 148 frames from video: id20_0004_faces
# Extracted 148 frames from video: id35_0004_faces
# Extracted 148 frames from video: id9_0002_faces
# Extracted 148 frames from video: id48_0008_faces
# Extracted 148 frames from video: id13_0015_faces
# Extracted 148 frames from video: id49_0003_faces
# Extracted 148 frames from video: id26_0002_faces
# Extracted 148 frames from video: id33_0002_faces
# Extracted 148 frames from video: id32_0009_faces
# Extracted 148 frames from video: id27_0009_faces
# Extracted 148 frames from video: id44_0004_faces
# Extracted 148 frames from video: id51_0004_faces
# Extracted 148 frames from video: id39_0008_faces
# Extracted 148 frames from video: id4_0005_faces
# Extracted 148 frames from video: id38_0003_faces
# Extracted 148 frames from video: id42_0002_faces
# Extracted 148 frames from video: id57_0002_faces
# Extracted 148 frames from video: id56_0009_faces
# Extracted 148 frames from video: id43_0009_faces
# Extracted 148 frames from video: id13_0001_faces
# Extracted 148 frames from video: id2_0003_faces
# Extracted 148 frames from video: id3_0008_faces
# Extracted 148 frames from video: id26_0009_faces
# Extracted 148 frames from video: id33_0009_faces
# Extracted 148 frames from video: id32_0002_faces
# Extracted 148 frames from video: id27_0002_faces
# Extracted 148 frames from video: id48_0003_faces
# Extracted 148 frames from video: id19_0000_faces
# Extracted 148 frames from video: id49_0008_faces
# Extracted 148 frames from video: id8_0002_faces
# Extracted 148 frames from video: id34_0004_faces
# Extracted 148 frames from video: id21_0004_faces
# Extracted 148 frames from video: id9_0009_faces
# Extracted 148 frames from video: id2_0008_faces
# Extracted 148 frames from video: id3_0003_faces
# Extracted 148 frames from video: id12_0001_faces
# Extracted 148 frames from video: id57_0009_faces
# Extracted 148 frames from video: id56_0002_faces
# Extracted 148 frames from video: id43_0002_faces
# Extracted 148 frames from video: id39_0003_faces
# Extracted 148 frames from video: id5_0005_faces
# Extracted 148 frames from video: id38_0008_faces
# Extracted 148 frames from video: id50_0004_faces
# Extracted 148 frames from video: id45_0004_faces
# Extracted 148 frames from video: id58_0004_faces
# Extracted 148 frames from video: id60_0000_faces
# Extracted 148 frames from video: id30_0008_faces
# Extracted 148 frames from video: id25_0008_faces
# Extracted 148 frames from video: id24_0003_faces
# Extracted 148 frames from video: id31_0003_faces
# Extracted 148 frames from video: id22_0005_faces
# Extracted 148 frames from video: id37_0005_faces
# Extracted 148 frames from video: id1_0009_faces
# Extracted 148 frames from video: id0_0002_faces
# Extracted 148 frames from video: id29_0004_faces
# Extracted 148 frames from video: id11_0000_faces
# Extracted 148 frames from video: id54_0008_faces
# Extracted 148 frames from video: id41_0008_faces
# Extracted 148 frames from video: id40_0003_faces
# Extracted 148 frames from video: id55_0003_faces
# Extracted 148 frames from video: id6_0004_faces
# Extracted 148 frames from video: id46_0005_faces
# Extracted 148 frames from video: id53_0005_faces
# Extracted 148 frames from video: id17_0006_faces
# Extracted 148 frames from video: id26_0004_faces
# Extracted 148 frames from video: id33_0004_faces
# Extracted 148 frames from video: id9_0004_faces
# Extracted 148 frames from video: id20_0002_faces
# Extracted 148 frames from video: id35_0002_faces
# Extracted 148 frames from video: id34_0009_faces
# Extracted 148 frames from video: id21_0009_faces
# Extracted 148 frames from video: id49_0005_faces
# Extracted 148 frames from video: id13_0013_faces
# Extracted 148 frames from video: id13_0007_faces
# Extracted 148 frames from video: id42_0004_faces
# Extracted 148 frames from video: id57_0004_faces
# Extracted 148 frames from video: id2_0005_faces
# Extracted 148 frames from video: id44_0002_faces
# Extracted 148 frames from video: id51_0002_faces
# Extracted 148 frames from video: id50_0009_faces
# Extracted 148 frames from video: id45_0009_faces
# Extracted 148 frames from video: id38_0005_faces
# Extracted 148 frames from video: id4_0003_faces
# Extracted 148 frames from video: id5_0008_faces
# Extracted 148 frames from video: id61_0006_faces
# Extracted 148 frames from video: id30_0005_faces
# Extracted 148 frames from video: id25_0005_faces
# Extracted 148 frames from video: id58_0009_faces
# Extracted 148 frames from video: id59_0002_faces
# Extracted 148 frames from video: id36_0003_faces
# Extracted 148 frames from video: id23_0003_faces
# Extracted 148 frames from video: id22_0008_faces
# Extracted 148 frames from video: id37_0008_faces
# Extracted 140 frames from video: id10_0006_faces
# Extracted 148 frames from video: id54_0005_faces
# Extracted 148 frames from video: id41_0005_faces
# Extracted 148 frames from video: id29_0009_faces
# Extracted 148 frames from video: id1_0004_faces
# Extracted 148 frames from video: id28_0002_faces
# Extracted 148 frames from video: id52_0003_faces
# Extracted 148 frames from video: id47_0003_faces
# Extracted 148 frames from video: id46_0008_faces
# Extracted 148 frames from video: id53_0008_faces
# Extracted 148 frames from video: id16_0000_faces
# Extracted 148 frames from video: id7_0002_faces
# Extracted 148 frames from video: id6_0009_faces
# Extracted 148 frames from video: id50_0001_faces
# Extracted 148 frames from video: id45_0001_faces
# Extracted 148 frames from video: id39_0006_faces
# Extracted 148 frames from video: id5_0000_faces
# Extracted 148 frames from video: id12_0004_faces
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 13
#      10 video_dataset = VideoDataset(video_dir=dataset_path, output_dir=output_dir)
#      12 # Extract frames for all videos in the dataset
# ---> 13 video_dataset.extract_frames()
#
# Cell In[18], line 82, in VideoDataset.extract_frames(self)
#      80     # Save each frame as a .jpg file
#      81     frame_filename = os.path.join(video_output_dir, f'frame_{frame_count:04d}.jpg')
# ---> 82     cv2.imwrite(frame_filename, frame)
#      83     frame_count += 1
#      85 cap.release()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Extract frames for TRANSFORMED

# %%
import os
import cv2
from PIL import Image
from torchvision import transforms

# %%
# Set the main directory path for extracted frames and transformed frames
extracted_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames'
transformed_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames/transformed'

# Create the directory for transformed frames if it doesn't exist
if not os.path.exists(transformed_frames_main_dir):
    os.makedirs(transformed_frames_main_dir)

# Transformation for the frames with data augmentation
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((112, 112)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.ToTensor()
])

# Custom class to load videos, extract frames, and save transformed frames
class VideoDataset:
    def __init__(self, video_dir, output_dir, transformed_output_dir):
        self.video_dir = video_dir
        self.output_dir = output_dir
        self.transformed_output_dir = transformed_output_dir
        self.video_files = [os.path.join(video_dir, f) for f in os.listdir(video_dir) if f.endswith('.mp4')]
        self.valid_video_files = self._filter_valid_videos()

    def _filter_valid_videos(self):
        valid_videos = []
        for video_path in self.video_files:
            cap = cv2.VideoCapture(video_path)
            valid = False
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                valid = True
                break
            cap.release()
            if valid:
                valid_videos.append(video_path)
            else:
                print(f"No frames extracted from video: {video_path}")
        return valid_videos

    def extract_and_transform_frames(self):
        """
        Extracts frames from each video, transforms them, and saves both original and transformed frames in a structured directory.
        """
        for video_path in self.valid_video_files:
            cap = cv2.VideoCapture(video_path)
            video_name = os.path.splitext(os.path.basename(video_path))[0]

            # Define the output directories for this video's frames
            video_output_dir = os.path.join(self.output_dir, video_name)
            transformed_output_dir = os.path.join(self.transformed_output_dir, video_name)

            # Create directories if they do not exist
            os.makedirs(video_output_dir, exist_ok=True)
            os.makedirs(transformed_output_dir, exist_ok=True)

            frame_count = 0
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                # Save each original frame as a .jpg file
                frame_filename = os.path.join(video_output_dir, f'frame_{frame_count:04d}.jpg')
                cv2.imwrite(frame_filename, frame)

                # Convert the frame from BGR to RGB for transformation
                frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

                # Apply transformations to the frame
                transformed_frame = transform(frame_rgb)

                # Convert transformed frame back to a format suitable for saving as an image
                transformed_frame_np = (transformed_frame.permute(1, 2, 0).numpy() * 255).astype('uint8')

                # Save transformed frame
                transformed_frame_filename = os.path.join(transformed_output_dir, f'transformed_frame_{frame_count:04d}.jpg')
                cv2.imwrite(transformed_frame_filename, cv2.cvtColor(transformed_frame_np, cv2.COLOR_RGB2BGR))

                frame_count += 1

            cap.release()
            print(f"Extracted and transformed {frame_count} frames from video: {video_name}")

# Define paths for the datasets
datasets = {
    'celebdf_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real',
    'celebdf_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf fake',
    'ff_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real',
    'ff_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake'
}

# %%
# Extract and transform frames for each dataset
for dataset_name, dataset_path in datasets.items():
    print(f"Processing dataset: {dataset_name}")

    # Define the output directories for extracted and transformed frames for this dataset
    output_dir = os.path.join(extracted_frames_main_dir, dataset_name)
    transformed_output_dir = os.path.join(transformed_frames_main_dir, dataset_name)

    # Create directories if they do not exist
    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(transformed_output_dir, exist_ok=True)

    # Create a VideoDataset instance for this dataset
    video_dataset = VideoDataset(video_dir=dataset_path, output_dir=output_dir, transformed_output_dir=transformed_output_dir)

    # Extract and transform frames for all videos in the dataset
    video_dataset.extract_and_transform_frames()
# Out:
# Processing dataset: celebdf_real
# No frames extracted from video: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real/id27_0005_faces.mp4
# OpenCV: Couldn't read video stream from file "/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real/id27_0005_faces.mp4"
# Extracted and transformed 148 frames from video: id6_0003_faces
# Extracted and transformed 148 frames from video: id7_0008_faces
# Extracted and transformed 148 frames from video: id46_0002_faces
# Extracted and transformed 148 frames from video: id53_0002_faces
# Extracted and transformed 148 frames from video: id17_0001_faces
# Extracted and transformed 148 frames from video: id52_0009_faces
# Extracted and transformed 148 frames from video: id47_0009_faces
# Extracted and transformed 148 frames from video: id28_0008_faces
# Extracted and transformed 148 frames from video: id0_0005_faces
# Extracted and transformed 148 frames from video: id29_0003_faces
# Extracted and transformed 148 frames from video: id11_0007_faces
# Extracted and transformed 148 frames from video: id40_0004_faces
# Extracted and transformed 148 frames from video: id55_0004_faces
# Extracted and transformed 148 frames from video: id22_0002_faces
# Extracted and transformed 148 frames from video: id37_0002_faces
# Extracted and transformed 148 frames from video: id36_0009_faces
# Extracted and transformed 148 frames from video: id23_0009_faces
# Extracted and transformed 148 frames from video: id59_0008_faces
# Extracted and transformed 148 frames from video: id58_0003_faces
# Extracted and transformed 148 frames from video: id60_0007_faces
# Extracted and transformed 148 frames from video: id24_0004_faces
# Extracted and transformed 148 frames from video: id31_0004_faces
# Extracted and transformed 148 frames from video: id39_0004_faces
# Extracted and transformed 148 frames from video: id5_0002_faces
# Extracted and transformed 148 frames from video: id4_0009_faces
# Extracted and transformed 148 frames from video: id50_0003_faces
# Extracted and transformed 148 frames from video: id45_0003_faces
# Extracted and transformed 148 frames from video: id51_0008_faces
# Extracted and transformed 148 frames from video: id3_0004_faces
# Extracted and transformed 148 frames from video: id12_0006_faces
# Extracted and transformed 148 frames from video: id56_0005_faces
# Extracted and transformed 148 frames from video: id43_0005_faces
# Extracted and transformed 148 frames from video: id48_0004_faces
# Extracted and transformed 148 frames from video: id19_0007_faces
# Extracted and transformed 148 frames from video: id8_0005_faces
# Extracted and transformed 148 frames from video: id34_0003_faces
# Extracted and transformed 124 frames from video: id21_0003_faces
# Extracted and transformed 148 frames from video: id20_0008_faces
# Extracted and transformed 148 frames from video: id35_0008_faces
# Extracted and transformed 148 frames from video: id32_0005_faces
# Extracted and transformed 148 frames from video: id52_0004_faces
# Extracted and transformed 148 frames from video: id47_0004_faces
# Extracted and transformed 148 frames from video: id16_0007_faces
# Extracted and transformed 148 frames from video: id7_0005_faces
# Extracted and transformed 148 frames from video: id40_0009_faces
# Extracted and transformed 148 frames from video: id55_0009_faces
# Extracted and transformed 76 frames from video: id10_0001_faces
# Extracted and transformed 148 frames from video: id54_0002_faces
# Extracted and transformed 148 frames from video: id41_0002_faces
# Extracted and transformed 148 frames from video: id0_0008_faces
# Extracted and transformed 148 frames from video: id1_0003_faces
# Extracted and transformed 148 frames from video: id28_0005_faces
# Extracted and transformed 148 frames from video: id36_0004_faces
# Extracted and transformed 148 frames from video: id23_0004_faces
# Extracted and transformed 148 frames from video: id24_0009_faces
# Extracted and transformed 148 frames from video: id31_0009_faces
# Extracted and transformed 8 frames from video: id61_0001_faces
# Extracted and transformed 148 frames from video: id30_0002_faces
# Extracted and transformed 148 frames from video: id25_0002_faces
# Extracted and transformed 148 frames from video: id16_0013_faces
# Extracted and transformed 148 frames from video: id59_0005_faces
# Extracted and transformed 148 frames from video: id44_0005_faces
# Extracted and transformed 148 frames from video: id51_0005_faces
# Extracted and transformed 148 frames from video: id38_0002_faces
# Extracted and transformed 148 frames from video: id4_0004_faces
# Extracted and transformed 148 frames from video: id39_0009_faces
# Extracted and transformed 148 frames from video: id56_0008_faces
# Extracted and transformed 148 frames from video: id43_0008_faces
# Extracted and transformed 148 frames from video: id13_0000_faces
# Extracted and transformed 148 frames from video: id42_0003_faces
# Extracted and transformed 148 frames from video: id57_0003_faces
# Extracted and transformed 148 frames from video: id3_0009_faces
# Extracted and transformed 148 frames from video: id2_0002_faces
# Extracted and transformed 148 frames from video: id9_0003_faces
# Extracted and transformed 148 frames from video: id20_0005_faces
# Extracted and transformed 148 frames from video: id35_0005_faces
# Extracted and transformed 148 frames from video: id8_0008_faces
# Extracted and transformed 148 frames from video: id49_0002_faces
# Extracted and transformed 148 frames from video: id48_0009_faces
# Extracted and transformed 148 frames from video: id13_0014_faces
# Extracted and transformed 148 frames from video: id32_0008_faces
# Extracted and transformed 148 frames from video: id27_0008_faces
# Extracted and transformed 148 frames from video: id26_0003_faces
# Extracted and transformed 148 frames from video: id33_0003_faces
# Extracted and transformed 148 frames from video: id3_0002_faces
# Extracted and transformed 148 frames from video: id2_0009_faces
# Extracted and transformed 148 frames from video: id56_0003_faces
# Extracted and transformed 148 frames from video: id43_0003_faces
# Extracted and transformed 148 frames from video: id12_0000_faces
# Extracted and transformed 148 frames from video: id57_0008_faces
# Extracted and transformed 148 frames from video: id38_0009_faces
# Extracted and transformed 148 frames from video: id5_0004_faces
# Extracted and transformed 148 frames from video: id39_0002_faces
# Extracted and transformed 148 frames from video: id50_0005_faces
# Extracted and transformed 148 frames from video: id45_0005_faces
# Extracted and transformed 148 frames from video: id32_0003_faces
# Extracted and transformed 148 frames from video: id27_0003_faces
# Extracted and transformed 148 frames from video: id26_0008_faces
# Extracted and transformed 148 frames from video: id33_0008_faces
# Extracted and transformed 148 frames from video: id19_0001_faces
# Extracted and transformed 148 frames from video: id49_0009_faces
# Extracted and transformed 148 frames from video: id48_0002_faces
# Extracted and transformed 148 frames from video: id9_0008_faces
# Extracted and transformed 148 frames from video: id34_0005_faces
# Extracted and transformed 148 frames from video: id21_0005_faces
# Extracted and transformed 144 frames from video: id8_0003_faces
# Extracted and transformed 148 frames from video: id29_0005_faces
# Extracted and transformed 148 frames from video: id0_0003_faces
# Extracted and transformed 112 frames from video: id1_0008_faces
# Extracted and transformed 148 frames from video: id40_0002_faces
# Extracted and transformed 148 frames from video: id55_0002_faces
# Extracted and transformed 148 frames from video: id11_0001_faces
# Extracted and transformed 148 frames from video: id54_0009_faces
# Extracted and transformed 148 frames from video: id41_0009_faces
# Extracted and transformed 148 frames from video: id6_0005_faces
# Extracted and transformed 148 frames from video: id17_0007_faces
# Extracted and transformed 148 frames from video: id46_0004_faces
# Extracted and transformed 148 frames from video: id53_0004_faces
# Extracted and transformed 148 frames from video: id58_0005_faces
# Extracted and transformed 148 frames from video: id24_0002_faces
# Extracted and transformed 148 frames from video: id31_0002_faces
# Extracted and transformed 148 frames from video: id60_0001_faces
# Extracted and transformed 148 frames from video: id30_0009_faces
# Extracted and transformed 148 frames from video: id25_0009_faces
# Extracted and transformed 148 frames from video: id22_0004_faces
# Extracted and transformed 148 frames from video: id37_0004_faces
# Extracted and transformed 148 frames from video: id57_0005_faces
# Extracted and transformed 148 frames from video: id13_0006_faces
# Extracted and transformed 148 frames from video: id2_0004_faces
# Extracted and transformed 148 frames from video: id50_0008_faces
# Extracted and transformed 148 frames from video: id45_0008_faces
# Extracted and transformed 148 frames from video: id44_0003_faces
# Extracted and transformed 148 frames from video: id51_0003_faces
# Extracted and transformed 148 frames from video: id5_0009_faces
# Extracted and transformed 148 frames from video: id4_0002_faces
# Extracted and transformed 148 frames from video: id38_0004_faces
# Extracted and transformed 148 frames from video: id26_0005_faces
# Extracted and transformed 148 frames from video: id33_0005_faces
# Extracted and transformed 148 frames from video: id34_0008_faces
# Extracted and transformed 148 frames from video: id21_0008_faces
# Extracted and transformed 148 frames from video: id20_0003_faces
# Extracted and transformed 148 frames from video: id35_0003_faces
# Extracted and transformed 148 frames from video: id9_0005_faces
# Extracted and transformed 148 frames from video: id13_0012_faces
# Extracted and transformed 148 frames from video: id49_0004_faces
# Extracted and transformed 148 frames from video: id54_0004_faces
# Extracted and transformed 148 frames from video: id41_0004_faces
# Extracted and transformed 148 frames from video: id10_0007_faces
# Extracted and transformed 148 frames from video: id28_0003_faces
# Extracted and transformed 148 frames from video: id1_0005_faces
# Extracted and transformed 148 frames from video: id29_0008_faces
# Extracted and transformed 148 frames from video: id46_0009_faces
# Extracted and transformed 148 frames from video: id53_0009_faces
# Extracted and transformed 148 frames from video: id16_0001_faces
# Extracted and transformed 148 frames from video: id52_0002_faces
# Extracted and transformed 148 frames from video: id47_0002_faces
# Extracted and transformed 148 frames from video: id6_0008_faces
# Extracted and transformed 148 frames from video: id7_0003_faces
# Extracted and transformed 148 frames from video: id25_0010_faces
# Extracted and transformed 148 frames from video: id30_0004_faces
# Extracted and transformed 148 frames from video: id25_0004_faces
# Extracted and transformed 140 frames from video: id61_0007_faces
# Extracted and transformed 148 frames from video: id59_0003_faces
# Extracted and transformed 148 frames from video: id58_0008_faces
# Extracted and transformed 148 frames from video: id22_0009_faces
# Extracted and transformed 148 frames from video: id37_0009_faces
# Extracted and transformed 148 frames from video: id36_0002_faces
# Extracted and transformed 148 frames from video: id23_0002_faces
# Extracted and transformed 148 frames from video: id36_0008_faces
# Extracted and transformed 148 frames from video: id23_0008_faces
# Extracted and transformed 148 frames from video: id22_0003_faces
# Extracted and transformed 148 frames from video: id37_0003_faces
# Extracted and transformed 148 frames from video: id58_0002_faces
# Extracted and transformed 148 frames from video: id59_0009_faces
# Extracted and transformed 148 frames from video: id24_0005_faces
# Extracted and transformed 148 frames from video: id31_0005_faces
# Extracted and transformed 104 frames from video: id60_0006_faces
# Extracted and transformed 148 frames from video: id7_0009_faces
# Extracted and transformed 148 frames from video: id6_0002_faces
# Extracted and transformed 148 frames from video: id17_0000_faces
# Extracted and transformed 148 frames from video: id52_0008_faces
# Extracted and transformed 148 frames from video: id47_0008_faces
# Extracted and transformed 148 frames from video: id46_0003_faces
# Extracted and transformed 148 frames from video: id53_0003_faces
# Extracted and transformed 148 frames from video: id29_0002_faces
# Extracted and transformed 148 frames from video: id0_0004_faces
# Extracted and transformed 148 frames from video: id28_0009_faces
# Extracted and transformed 148 frames from video: id40_0005_faces
# Extracted and transformed 148 frames from video: id55_0005_faces
# Extracted and transformed 148 frames from video: id11_0006_faces
# Extracted and transformed 148 frames from video: id19_0006_faces
# Extracted and transformed 148 frames from video: id48_0005_faces
# Extracted and transformed 148 frames from video: id20_0009_faces
# Extracted and transformed 148 frames from video: id35_0009_faces
# Extracted and transformed 148 frames from video: id34_0002_faces
# Extracted and transformed 148 frames from video: id21_0002_faces
# Extracted and transformed 148 frames from video: id8_0004_faces
# Extracted and transformed 148 frames from video: id32_0004_faces
# Extracted and transformed 148 frames from video: id27_0004_faces
# Extracted and transformed 148 frames from video: id4_0008_faces
# Extracted and transformed 148 frames from video: id5_0003_faces
# Extracted and transformed 148 frames from video: id39_0005_faces
# Extracted and transformed 148 frames from video: id51_0009_faces
# Extracted and transformed 148 frames from video: id50_0002_faces
# Extracted and transformed 148 frames from video: id45_0002_faces
# Extracted and transformed 148 frames from video: id3_0005_faces
# Extracted and transformed 148 frames from video: id56_0004_faces
# Extracted and transformed 148 frames from video: id43_0004_faces
# Extracted and transformed 148 frames from video: id36_0005_faces
# Extracted and transformed 148 frames from video: id23_0005_faces
# Extracted and transformed 148 frames from video: id30_0003_faces
# Extracted and transformed 148 frames from video: id25_0003_faces
# Extracted and transformed 148 frames from video: id24_0008_faces
# Extracted and transformed 148 frames from video: id31_0008_faces
# Extracted and transformed 148 frames from video: id61_0000_faces
# Extracted and transformed 148 frames from video: id59_0004_faces
# Extracted and transformed 148 frames from video: id16_0012_faces
# Extracted and transformed 148 frames from video: id16_0006_faces
# Extracted and transformed 148 frames from video: id52_0005_faces
# Extracted and transformed 148 frames from video: id47_0005_faces
# Extracted and transformed 148 frames from video: id7_0004_faces
# Extracted and transformed 148 frames from video: id54_0003_faces
# Extracted and transformed 148 frames from video: id41_0003_faces
# Extracted and transformed 148 frames from video: id40_0008_faces
# Extracted and transformed 148 frames from video: id55_0008_faces
# Extracted and transformed 148 frames from video: id10_0000_faces
# Extracted and transformed 148 frames from video: id28_0004_faces
# Extracted and transformed 148 frames from video: id1_0002_faces
# Extracted and transformed 148 frames from video: id0_0009_faces
# Extracted and transformed 148 frames from video: id8_0009_faces
# Extracted and transformed 148 frames from video: id20_0004_faces
# Extracted and transformed 148 frames from video: id35_0004_faces
# Extracted and transformed 148 frames from video: id9_0002_faces
# Extracted and transformed 148 frames from video: id48_0008_faces
# Extracted and transformed 148 frames from video: id13_0015_faces
# Extracted and transformed 148 frames from video: id49_0003_faces
# Extracted and transformed 148 frames from video: id26_0002_faces
# Extracted and transformed 148 frames from video: id33_0002_faces
# Extracted and transformed 148 frames from video: id32_0009_faces
# Extracted and transformed 148 frames from video: id27_0009_faces
# Extracted and transformed 148 frames from video: id44_0004_faces
# Extracted and transformed 148 frames from video: id51_0004_faces
# Extracted and transformed 148 frames from video: id39_0008_faces
# Extracted and transformed 148 frames from video: id4_0005_faces
# Extracted and transformed 148 frames from video: id38_0003_faces
# Extracted and transformed 148 frames from video: id42_0002_faces
# Extracted and transformed 148 frames from video: id57_0002_faces
# Extracted and transformed 148 frames from video: id56_0009_faces
# Extracted and transformed 148 frames from video: id43_0009_faces
# Extracted and transformed 148 frames from video: id13_0001_faces
# Extracted and transformed 148 frames from video: id2_0003_faces
# Extracted and transformed 148 frames from video: id3_0008_faces
# Extracted and transformed 148 frames from video: id26_0009_faces
# Extracted and transformed 148 frames from video: id33_0009_faces
# Extracted and transformed 148 frames from video: id32_0002_faces
# Extracted and transformed 148 frames from video: id27_0002_faces
# Extracted and transformed 148 frames from video: id48_0003_faces
# Extracted and transformed 148 frames from video: id19_0000_faces
# Extracted and transformed 148 frames from video: id49_0008_faces
# Extracted and transformed 148 frames from video: id8_0002_faces
# Extracted and transformed 148 frames from video: id34_0004_faces
# Extracted and transformed 148 frames from video: id21_0004_faces
# Extracted and transformed 148 frames from video: id9_0009_faces
# Extracted and transformed 148 frames from video: id2_0008_faces
# Extracted and transformed 148 frames from video: id3_0003_faces
# Extracted and transformed 148 frames from video: id12_0001_faces
# Extracted and transformed 148 frames from video: id57_0009_faces
# Extracted and transformed 148 frames from video: id56_0002_faces
# Extracted and transformed 148 frames from video: id43_0002_faces
# Extracted and transformed 148 frames from video: id39_0003_faces
# Extracted and transformed 148 frames from video: id5_0005_faces
# Extracted and transformed 148 frames from video: id38_0008_faces
# Extracted and transformed 148 frames from video: id50_0004_faces
# Extracted and transformed 148 frames from video: id45_0004_faces
# Extracted and transformed 148 frames from video: id58_0004_faces
# Extracted and transformed 148 frames from video: id60_0000_faces
# Extracted and transformed 148 frames from video: id30_0008_faces
# Extracted and transformed 148 frames from video: id25_0008_faces
# Extracted and transformed 148 frames from video: id24_0003_faces
# Extracted and transformed 148 frames from video: id31_0003_faces
# Extracted and transformed 148 frames from video: id22_0005_faces
# Extracted and transformed 148 frames from video: id37_0005_faces
# Extracted and transformed 148 frames from video: id1_0009_faces
# Extracted and transformed 148 frames from video: id0_0002_faces
# Extracted and transformed 148 frames from video: id29_0004_faces
# Extracted and transformed 148 frames from video: id11_0000_faces
# Extracted and transformed 148 frames from video: id54_0008_faces
# Extracted and transformed 148 frames from video: id41_0008_faces
# Extracted and transformed 148 frames from video: id40_0003_faces
# Extracted and transformed 148 frames from video: id55_0003_faces
# Extracted and transformed 148 frames from video: id6_0004_faces
# Extracted and transformed 148 frames from video: id46_0005_faces
# Extracted and transformed 148 frames from video: id53_0005_faces
# Extracted and transformed 148 frames from video: id17_0006_faces
# Extracted and transformed 148 frames from video: id26_0004_faces
# Extracted and transformed 148 frames from video: id33_0004_faces
# Extracted and transformed 148 frames from video: id9_0004_faces
# Extracted and transformed 148 frames from video: id20_0002_faces
# Extracted and transformed 148 frames from video: id35_0002_faces
# Extracted and transformed 148 frames from video: id34_0009_faces
# Extracted and transformed 148 frames from video: id21_0009_faces
# Extracted and transformed 148 frames from video: id49_0005_faces
# Extracted and transformed 148 frames from video: id13_0013_faces
# Extracted and transformed 148 frames from video: id13_0007_faces
# Extracted and transformed 148 frames from video: id42_0004_faces
# Extracted and transformed 148 frames from video: id57_0004_faces
# Extracted and transformed 148 frames from video: id2_0005_faces
# Extracted and transformed 148 frames from video: id44_0002_faces
# Extracted and transformed 148 frames from video: id51_0002_faces
# Extracted and transformed 148 frames from video: id50_0009_faces
# Extracted and transformed 148 frames from video: id45_0009_faces
# Extracted and transformed 148 frames from video: id38_0005_faces
# Extracted and transformed 148 frames from video: id4_0003_faces
# Extracted and transformed 148 frames from video: id5_0008_faces
# Extracted and transformed 148 frames from video: id61_0006_faces
# Extracted and transformed 148 frames from video: id30_0005_faces
# Extracted and transformed 148 frames from video: id25_0005_faces
# Extracted and transformed 148 frames from video: id58_0009_faces
# Extracted and transformed 148 frames from video: id59_0002_faces
# Extracted and transformed 148 frames from video: id36_0003_faces
# Extracted and transformed 148 frames from video: id23_0003_faces
# Extracted and transformed 148 frames from video: id22_0008_faces
# Extracted and transformed 148 frames from video: id37_0008_faces
# Extracted and transformed 140 frames from video: id10_0006_faces
# Extracted and transformed 148 frames from video: id54_0005_faces
# Extracted and transformed 148 frames from video: id41_0005_faces
# Extracted and transformed 148 frames from video: id29_0009_faces
# Extracted and transformed 148 frames from video: id1_0004_faces
# Extracted and transformed 148 frames from video: id28_0002_faces
# Extracted and transformed 148 frames from video: id52_0003_faces
# Extracted and transformed 148 frames from video: id47_0003_faces
# Extracted and transformed 148 frames from video: id46_0008_faces
# Extracted and transformed 148 frames from video: id53_0008_faces
# Extracted and transformed 148 frames from video: id16_0000_faces
# Extracted and transformed 148 frames from video: id7_0002_faces
# Extracted and transformed 148 frames from video: id6_0009_faces
# Extracted and transformed 148 frames from video: id50_0001_faces
# Extracted and transformed 148 frames from video: id45_0001_faces
# Extracted and transformed 148 frames from video: id39_0006_faces
# Extracted and transformed 148 frames from video: id5_0000_faces
# Extracted and transformed 148 frames from video: id12_0004_faces
# Extracted and transformed 148 frames from video: id56_0007_faces
# Extracted and transformed 148 frames from video: id43_0007_faces
# Extracted and transformed 148 frames from video: id3_0006_faces
# Extracted and transformed 148 frames from video: id8_0007_faces
# Extracted and transformed 148 frames from video: id34_0001_faces
# Extracted and transformed 148 frames from video: id21_0001_faces
# Extracted and transformed 148 frames from video: id48_0006_faces
# Extracted and transformed 148 frames from video: id19_0005_faces
# Extracted and transformed 148 frames from video: id32_0007_faces
# Extracted and transformed 148 frames from video: id27_0007_faces
# Extracted and transformed 132 frames from video: id16_0008_faces
# Extracted and transformed 148 frames from video: id46_0000_faces
# Extracted and transformed 148 frames from video: id53_0000_faces
# Extracted and transformed 148 frames from video: id17_0003_faces
# Extracted and transformed 148 frames from video: id6_0001_faces
# Extracted and transformed 148 frames from video: id11_0005_faces
# Extracted and transformed 148 frames from video: id40_0006_faces
# Extracted and transformed 148 frames from video: id55_0006_faces
# Extracted and transformed 148 frames from video: id0_0007_faces
# Extracted and transformed 144 frames from video: id29_0001_faces
# Extracted and transformed 148 frames from video: id22_0000_faces
# Extracted and transformed 148 frames from video: id37_0000_faces
# Extracted and transformed 140 frames from video: id60_0005_faces
# Extracted and transformed 148 frames from video: id24_0006_faces
# Extracted and transformed 148 frames from video: id31_0006_faces
# Extracted and transformed 148 frames from video: id58_0001_faces
# Extracted and transformed 148 frames from video: id38_0000_faces
# Extracted and transformed 148 frames from video: id4_0006_faces
# Extracted and transformed 148 frames from video: id51_0007_faces
# Extracted and transformed 148 frames from video: id2_0000_faces
# Extracted and transformed 148 frames from video: id13_0002_faces
# Extracted and transformed 148 frames from video: id42_0001_faces
# Extracted and transformed 148 frames from video: id57_0001_faces
# Extracted and transformed 148 frames from video: id49_0000_faces
# Extracted and transformed 148 frames from video: id19_0008_faces
# Extracted and transformed 148 frames from video: id9_0001_faces
# Extracted and transformed 148 frames from video: id20_0007_faces
# Extracted and transformed 148 frames from video: id35_0007_faces
# Extracted and transformed 148 frames from video: id26_0001_faces
# Extracted and transformed 148 frames from video: id33_0001_faces
# Extracted and transformed 148 frames from video: id7_0007_faces
# Extracted and transformed 148 frames from video: id52_0006_faces
# Extracted and transformed 148 frames from video: id47_0006_faces
# Extracted and transformed 148 frames from video: id16_0005_faces
# Extracted and transformed 148 frames from video: id1_0001_faces
# Extracted and transformed 148 frames from video: id28_0007_faces
# Extracted and transformed 148 frames from video: id10_0003_faces
# Extracted and transformed 148 frames from video: id54_0000_faces
# Extracted and transformed 148 frames from video: id41_0000_faces
# Extracted and transformed 148 frames from video: id11_0008_faces
# Extracted and transformed 148 frames from video: id36_0006_faces
# Extracted and transformed 148 frames from video: id23_0006_faces
# Extracted and transformed 148 frames from video: id16_0011_faces
# Extracted and transformed 148 frames from video: id59_0007_faces
# Extracted and transformed 116 frames from video: id61_0003_faces
# Extracted and transformed 140 frames from video: id30_0000_faces
# Extracted and transformed 148 frames from video: id25_0000_faces
# Extracted and transformed 80 frames from video: id60_0008_faces
# Extracted and transformed 148 frames from video: id10_0008_faces
# Extracted and transformed 148 frames from video: id40_0000_faces
# Extracted and transformed 148 frames from video: id55_0000_faces
# Extracted and transformed 148 frames from video: id11_0003_faces
# Extracted and transformed 148 frames from video: id29_0007_faces
# Extracted and transformed 148 frames from video: id0_0001_faces
# Extracted and transformed 148 frames from video: id17_0005_faces
# Extracted and transformed 148 frames from video: id46_0006_faces
# Extracted and transformed 148 frames from video: id53_0006_faces
# Extracted and transformed 148 frames from video: id6_0007_faces
# Extracted and transformed 148 frames from video: id61_0008_faces
# Extracted and transformed 148 frames from video: id24_0000_faces
# Extracted and transformed 148 frames from video: id31_0000_faces
# Extracted and transformed 136 frames from video: id60_0003_faces
# Extracted and transformed 148 frames from video: id58_0007_faces
# Extracted and transformed 148 frames from video: id22_0006_faces
# Extracted and transformed 148 frames from video: id37_0006_faces
# Extracted and transformed 148 frames from video: id13_0009_faces
# Extracted and transformed 148 frames from video: id56_0001_faces
# Extracted and transformed 148 frames from video: id43_0001_faces
# Extracted and transformed 148 frames from video: id12_0002_faces
# Extracted and transformed 148 frames from video: id3_0000_faces
# Extracted and transformed 148 frames from video: id50_0007_faces
# Extracted and transformed 140 frames from video: id45_0007_faces
# Extracted and transformed 148 frames from video: id5_0006_faces
# Extracted and transformed 148 frames from video: id39_0000_faces
# Extracted and transformed 148 frames from video: id32_0001_faces
# Extracted and transformed 148 frames from video: id27_0001_faces
# Extracted and transformed 144 frames from video: id34_0007_faces
# Extracted and transformed 148 frames from video: id21_0007_faces
# Extracted and transformed 148 frames from video: id8_0001_faces
# Extracted and transformed 148 frames from video: id19_0003_faces
# Extracted and transformed 148 frames from video: id48_0000_faces
# Extracted and transformed 148 frames from video: id28_0001_faces
# Extracted and transformed 148 frames from video: id1_0007_faces
# Extracted and transformed 148 frames from video: id54_0006_faces
# Extracted and transformed 148 frames from video: id41_0006_faces
# Extracted and transformed 148 frames from video: id10_0005_faces
# Extracted and transformed 148 frames from video: id7_0001_faces
# Extracted and transformed 148 frames from video: id16_0003_faces
# Extracted and transformed 148 frames from video: id52_0000_faces
# Extracted and transformed 148 frames from video: id47_0000_faces
# Extracted and transformed 148 frames from video: id17_0008_faces
# Extracted and transformed 148 frames from video: id59_0001_faces
# Extracted and transformed 148 frames from video: id30_0006_faces
# Extracted and transformed 148 frames from video: id25_0006_faces
# Extracted and transformed 148 frames from video: id61_0005_faces
# Extracted and transformed 148 frames from video: id36_0000_faces
# Extracted and transformed 148 frames from video: id23_0000_faces
# Extracted and transformed 148 frames from video: id2_0006_faces
# Extracted and transformed 148 frames from video: id57_0007_faces
# Extracted and transformed 148 frames from video: id13_0004_faces
# Extracted and transformed 148 frames from video: id4_0000_faces
# Extracted and transformed 148 frames from video: id38_0006_faces
# Extracted and transformed 148 frames from video: id44_0001_faces
# Extracted and transformed 148 frames from video: id51_0001_faces
# Extracted and transformed 148 frames from video: id26_0007_faces
# Extracted and transformed 148 frames from video: id33_0007_faces
# Extracted and transformed 148 frames from video: id13_0010_faces
# Extracted and transformed 148 frames from video: id49_0006_faces
# Extracted and transformed 148 frames from video: id20_0001_faces
# Extracted and transformed 148 frames from video: id35_0001_faces
# Extracted and transformed 148 frames from video: id9_0007_faces
# Extracted and transformed 148 frames from video: id34_0000_faces
# Extracted and transformed 148 frames from video: id21_0000_faces
# Extracted and transformed 148 frames from video: id8_0006_faces
# Extracted and transformed 148 frames from video: id19_0004_faces
# Extracted and transformed 148 frames from video: id48_0007_faces
# Extracted and transformed 144 frames from video: id32_0006_faces
# Extracted and transformed 148 frames from video: id27_0006_faces
# Extracted and transformed 148 frames from video: id50_0000_faces
# Extracted and transformed 148 frames from video: id45_0000_faces
# Extracted and transformed 148 frames from video: id5_0001_faces
# Extracted and transformed 148 frames from video: id39_0007_faces
# Extracted and transformed 148 frames from video: id56_0006_faces
# Extracted and transformed 148 frames from video: id43_0006_faces
# Extracted and transformed 148 frames from video: id12_0005_faces
# Extracted and transformed 148 frames from video: id3_0007_faces
# Extracted and transformed 148 frames from video: id22_0001_faces
# Extracted and transformed 148 frames from video: id37_0001_faces
# Extracted and transformed 148 frames from video: id11_0010_faces
# Extracted and transformed 148 frames from video: id24_0007_faces
# Extracted and transformed 148 frames from video: id31_0007_faces
# Extracted and transformed 148 frames from video: id60_0004_faces
# Extracted and transformed 148 frames from video: id58_0000_faces
# Extracted and transformed 148 frames from video: id17_0002_faces
# Extracted and transformed 148 frames from video: id16_0009_faces
# Extracted and transformed 148 frames from video: id46_0001_faces
# Extracted and transformed 148 frames from video: id53_0001_faces
# Extracted and transformed 148 frames from video: id6_0000_faces
# Extracted and transformed 148 frames from video: id40_0007_faces
# Extracted and transformed 148 frames from video: id55_0007_faces
# Extracted and transformed 136 frames from video: id11_0004_faces
# Extracted and transformed 148 frames from video: id29_0000_faces
# Extracted and transformed 148 frames from video: id0_0006_faces
# Extracted and transformed 148 frames from video: id49_0001_faces
# Extracted and transformed 148 frames from video: id19_0009_faces
# Extracted and transformed 148 frames from video: id20_0006_faces
# Extracted and transformed 148 frames from video: id35_0006_faces
# Extracted and transformed 148 frames from video: id9_0000_faces
# Extracted and transformed 148 frames from video: id26_0000_faces
# Extracted and transformed 140 frames from video: id33_0000_faces
# Extracted and transformed 148 frames from video: id4_0007_faces
# Extracted and transformed 148 frames from video: id38_0001_faces
# Extracted and transformed 148 frames from video: id51_0006_faces
# Extracted and transformed 148 frames from video: id2_0001_faces
# Extracted and transformed 148 frames from video: id42_0000_faces
# Extracted and transformed 148 frames from video: id57_0000_faces
# Extracted and transformed 148 frames from video: id13_0003_faces
# Extracted and transformed 148 frames from video: id36_0007_faces
# Extracted and transformed 148 frames from video: id23_0007_faces
# Extracted and transformed 148 frames from video: id59_0006_faces
# Extracted and transformed 148 frames from video: id16_0010_faces
# Extracted and transformed 148 frames from video: id30_0001_faces
# Extracted and transformed 148 frames from video: id25_0001_faces
# Extracted and transformed 148 frames from video: id60_0009_faces
# Extracted and transformed 148 frames from video: id61_0002_faces
# Extracted and transformed 148 frames from video: id7_0006_faces
# Extracted and transformed 148 frames from video: id16_0004_faces
# Extracted and transformed 128 frames from video: id52_0007_faces
# Extracted and transformed 148 frames from video: id47_0007_faces
# Extracted and transformed 148 frames from video: id28_0006_faces
# Extracted and transformed 148 frames from video: id1_0000_faces
# Extracted and transformed 148 frames from video: id54_0001_faces
# Extracted and transformed 148 frames from video: id41_0001_faces
# Extracted and transformed 148 frames from video: id11_0009_faces
# Extracted and transformed 148 frames from video: id10_0002_faces
# Extracted and transformed 100 frames from video: id60_0002_faces
# Extracted and transformed 148 frames from video: id61_0009_faces
# Extracted and transformed 148 frames from video: id24_0001_faces
# Extracted and transformed 148 frames from video: id31_0001_faces
# Extracted and transformed 148 frames from video: id58_0006_faces
# Extracted and transformed 148 frames from video: id22_0007_faces
# Extracted and transformed 148 frames from video: id37_0007_faces
# Extracted and transformed 148 frames from video: id11_0002_faces
# Extracted and transformed 148 frames from video: id10_0009_faces
# Extracted and transformed 148 frames from video: id40_0001_faces
# Extracted and transformed 148 frames from video: id55_0001_faces
# Extracted and transformed 148 frames from video: id0_0000_faces
# Extracted and transformed 148 frames from video: id29_0006_faces
# Extracted and transformed 148 frames from video: id46_0007_faces
# Extracted and transformed 148 frames from video: id53_0007_faces
# Extracted and transformed 148 frames from video: id17_0004_faces
# Extracted and transformed 148 frames from video: id6_0006_faces
# Extracted and transformed 148 frames from video: id32_0000_faces
# Extracted and transformed 148 frames from video: id27_0000_faces
# Extracted and transformed 148 frames from video: id8_0000_faces
# Extracted and transformed 148 frames from video: id34_0006_faces
# Extracted and transformed 148 frames from video: id21_0006_faces
# Extracted and transformed 148 frames from video: id48_0001_faces
# Extracted and transformed 148 frames from video: id19_0002_faces
# Extracted and transformed 148 frames from video: id12_0003_faces
# Extracted and transformed 148 frames from video: id13_0008_faces
# Extracted and transformed 148 frames from video: id56_0000_faces
# Extracted and transformed 148 frames from video: id43_0000_faces
# Extracted and transformed 148 frames from video: id3_0001_faces
# Extracted and transformed 148 frames from video: id50_0006_faces
# Extracted and transformed 148 frames from video: id45_0006_faces
# Extracted and transformed 148 frames from video: id39_0001_faces
# Extracted and transformed 148 frames from video: id5_0007_faces
# Extracted and transformed 144 frames from video: id59_0000_faces
# Extracted and transformed 148 frames from video: id61_0004_faces
# Extracted and transformed 148 frames from video: id30_0007_faces
# Extracted and transformed 148 frames from video: id25_0007_faces
# Extracted and transformed 148 frames from video: id36_0001_faces
# Extracted and transformed 148 frames from video: id23_0001_faces
# Extracted and transformed 148 frames from video: id1_0006_faces
# Extracted and transformed 148 frames from video: id28_0000_faces
# Extracted and transformed 148 frames from video: id10_0004_faces
# Extracted and transformed 148 frames from video: id54_0007_faces
# Extracted and transformed 148 frames from video: id41_0007_faces
# Extracted and transformed 148 frames from video: id7_0000_faces
# Extracted and transformed 148 frames from video: id52_0001_faces
# Extracted and transformed 148 frames from video: id47_0001_faces
# Extracted and transformed 148 frames from video: id17_0009_faces
# Extracted and transformed 148 frames from video: id16_0002_faces
# Extracted and transformed 148 frames from video: id26_0006_faces
# Extracted and transformed 148 frames from video: id33_0006_faces
# Extracted and transformed 148 frames from video: id49_0007_faces
# Extracted and transformed 148 frames from video: id13_0011_faces
# Extracted and transformed 148 frames from video: id9_0006_faces
# Extracted and transformed 148 frames from video: id20_0000_faces
# Extracted and transformed 148 frames from video: id35_0000_faces
# Extracted and transformed 148 frames from video: id2_0007_faces
# Extracted and transformed 148 frames from video: id13_0005_faces
# Extracted and transformed 148 frames from video: id57_0006_faces
# Extracted and transformed 148 frames from video: id38_0007_faces
# Extracted and transformed 148 frames from video: id4_0001_faces
# Extracted and transformed 148 frames from video: id44_0000_faces
# Extracted and transformed 148 frames from video: id51_0000_faces
# Processing dataset: celebdf_fake
# Extracted and transformed 148 frames from video: id54_id57_0001_faces
# Extracted and transformed 148 frames from video: id21_id16_0007_faces
# Extracted and transformed 148 frames from video: id38_id30_0002_faces
# Extracted and transformed 148 frames from video: id29_id35_0009_faces
# Extracted and transformed 148 frames from video: id35_id30_0008_faces
# Extracted and transformed 148 frames from video: id28_id17_0000_faces
# Extracted and transformed 148 frames from video: id4_id23_0000_faces
# Extracted and transformed 148 frames from video: id26_id27_0003_faces
# Extracted and transformed 148 frames from video: id30_id35_0009_faces
# Extracted and transformed 148 frames from video: id30_id21_0002_faces
# Extracted and transformed 148 frames from video: id21_id24_0009_faces
# Extracted and transformed 148 frames from video: id35_id4_0006_faces
# Extracted and transformed 148 frames from video: id40_id45_0006_faces
# Extracted and transformed 148 frames from video: id16_id20_0006_faces
# Extracted and transformed 148 frames from video: id33_id35_0004_faces
# Extracted and transformed 148 frames from video: id21_id38_0002_faces
# Extracted and transformed 148 frames from video: id43_id42_0006_faces
# Extracted and transformed 148 frames from video: id3_id17_0003_faces
# Extracted and transformed 148 frames from video: id56_id58_0001_faces
# Extracted and transformed 148 frames from video: id22_id24_0004_faces
# Extracted and transformed 148 frames from video: id33_id26_0002_faces
# Extracted and transformed 148 frames from video: id35_id38_0008_faces
# Extracted and transformed 148 frames from video: id55_id49_0000_faces
# Extracted and transformed 148 frames from video: id3_id31_0006_faces
# Extracted and transformed 148 frames from video: id27_id19_0001_faces
# Extracted and transformed 148 frames from video: id23_id0_0000_faces
# Extracted and transformed 148 frames from video: id1_id16_0005_faces
# Extracted and transformed 148 frames from video: id21_id27_0008_faces
# Extracted and transformed 148 frames from video: id47_id42_0000_faces
# Extracted and transformed 148 frames from video: id27_id26_0008_faces
# Extracted and transformed 148 frames from video: id56_id55_0006_faces
# Extracted and transformed 148 frames from video: id46_id47_0007_faces
# Extracted and transformed 148 frames from video: id23_id30_0002_faces
# Extracted and transformed 148 frames from video: id21_id6_0005_faces
# Extracted and transformed 148 frames from video: id16_id37_0001_faces
# Extracted and transformed 148 frames from video: id22_id20_0005_faces
# Extracted and transformed 148 frames from video: id23_id9_0006_faces
# Extracted and transformed 148 frames from video: id28_id16_0006_faces
# Extracted and transformed 148 frames from video: id6_id28_0001_faces
# Extracted and transformed 148 frames from video: id6_id0_0003_faces
# Extracted and transformed 148 frames from video: id21_id22_0002_faces
# Extracted and transformed 148 frames from video: id37_id30_0008_faces
# Extracted and transformed 148 frames from video: id31_id30_0003_faces
# Extracted and transformed 148 frames from video: id2_id30_0000_faces
# Extracted and transformed 148 frames from video: id26_id21_0008_faces
# Extracted and transformed 148 frames from video: id30_id26_0002_faces
# Extracted and transformed 148 frames from video: id34_id38_0005_faces
# Extracted and transformed 148 frames from video: id7_id13_0004_faces
# Extracted and transformed 148 frames from video: id26_id20_0003_faces
# Extracted and transformed 148 frames from video: id0_id16_0008_faces
# Extracted and transformed 148 frames from video: id17_id6_0002_faces
# Extracted and transformed 148 frames from video: id6_id17_0008_faces
# Extracted and transformed 148 frames from video: id55_id50_0001_faces
# Extracted and transformed 148 frames from video: id35_id21_0009_faces
# Extracted and transformed 148 frames from video: id47_id48_0007_faces
# Extracted and transformed 148 frames from video: id28_id20_0004_faces
# Extracted and transformed 148 frames from video: id54_id55_0006_faces
# Extracted and transformed 148 frames from video: id37_id2_0003_faces
# Extracted and transformed 148 frames from video: id28_id26_0002_faces
# Extracted and transformed 148 frames from video: id25_id21_0005_faces
# Extracted and transformed 148 frames from video: id43_id45_0006_faces
# Extracted and transformed 148 frames from video: id55_id56_0007_faces
# Extracted and transformed 148 frames from video: id0_id21_0001_faces
# Extracted and transformed 148 frames from video: id21_id3_0002_faces
# Extracted and transformed 148 frames from video: id47_id39_0007_faces
# Extracted and transformed 148 frames from video: id26_id30_0004_faces
# Extracted and transformed 148 frames from video: id2_id20_0007_faces
# Extracted and transformed 148 frames from video: id32_id29_0002_faces
# Extracted and transformed 148 frames from video: id20_id0_0006_faces
# Extracted and transformed 148 frames from video: id21_id35_0008_faces
# Extracted and transformed 148 frames from video: id53_id49_0006_faces
# Extracted and transformed 148 frames from video: id26_id37_0009_faces
# Extracted and transformed 148 frames from video: id10_id13_0005_faces
# Extracted and transformed 148 frames from video: id43_id48_0001_faces
# Extracted and transformed 148 frames from video: id31_id20_0004_faces
# Extracted and transformed 148 frames from video: id8_id2_0002_faces
# Extracted and transformed 148 frames from video: id6_id9_0003_faces
# Extracted and transformed 148 frames from video: id45_id39_0001_faces
# Extracted and transformed 148 frames from video: id30_id29_0004_faces
# Extracted and transformed 148 frames from video: id49_id52_0006_faces
# Extracted and transformed 148 frames from video: id21_id3_0009_faces
# Extracted and transformed 148 frames from video: id16_id20_0000_faces
# Extracted and transformed 148 frames from video: id29_id31_0003_faces
# Extracted and transformed 148 frames from video: id30_id17_0006_faces
# Extracted and transformed 148 frames from video: id25_id27_0008_faces
# Extracted and transformed 148 frames from video: id21_id38_0004_faces
# Extracted and transformed 148 frames from video: id45_id48_0001_faces
# Extracted and transformed 148 frames from video: id47_id42_0006_faces
# Extracted and transformed 148 frames from video: id37_id20_0004_faces
# Extracted and transformed 148 frames from video: id23_id6_0000_faces
# Extracted and transformed 148 frames from video: id20_id22_0009_faces
# Extracted and transformed 144 frames from video: id0_id1_0009_faces
# Extracted and transformed 148 frames from video: id20_id1_0006_faces
# Extracted and transformed 148 frames from video: id11_id7_0008_faces
# Extracted and transformed 148 frames from video: id26_id24_0004_faces
# Extracted and transformed 148 frames from video: id29_id21_0004_faces
# Extracted and transformed 148 frames from video: id34_id21_0002_faces
# Extracted and transformed 148 frames from video: id4_id3_0007_faces
# Extracted and transformed 148 frames from video: id28_id30_0008_faces
# Extracted and transformed 148 frames from video: id17_id35_0000_faces
# Extracted and transformed 148 frames from video: id27_id28_0008_faces
# Extracted and transformed 148 frames from video: id28_id24_0003_faces
# Extracted and transformed 148 frames from video: id29_id33_0009_faces
# Extracted and transformed 148 frames from video: id6_id31_0006_faces
# Extracted and transformed 148 frames from video: id38_id30_0004_faces
# Extracted and transformed 148 frames from video: id58_id55_0007_faces
# Extracted and transformed 148 frames from video: id39_id42_0005_faces
# Extracted and transformed 148 frames from video: id6_id16_0008_faces
# Extracted and transformed 148 frames from video: id26_id20_0008_faces
# Extracted and transformed 148 frames from video: id16_id28_0000_faces
# Extracted and transformed 148 frames from video: id23_id17_0007_faces
# Extracted and transformed 148 frames from video: id30_id32_0002_faces
# Extracted and transformed 148 frames from video: id16_id17_0009_faces
# Extracted and transformed 148 frames from video: id39_id45_0008_faces
# Extracted and transformed 148 frames from video: id27_id22_0002_faces
# Extracted and transformed 148 frames from video: id38_id29_0008_faces
# Extracted and transformed 148 frames from video: id56_id50_0007_faces
# Extracted and transformed 148 frames from video: id6_id0_0008_faces
# Extracted and transformed 148 frames from video: id2_id37_0006_faces
# Extracted and transformed 148 frames from video: id16_id30_0013_faces
# Extracted and transformed 148 frames from video: id23_id3_0007_faces
# Extracted and transformed 148 frames from video: id25_id20_0008_faces
# Extracted and transformed 148 frames from video: id1_id4_0006_faces
# Extracted and transformed 148 frames from video: id4_id1_0000_faces
# Extracted and transformed 148 frames from video: id29_id37_0008_faces
# Extracted and transformed 148 frames from video: id34_id31_0008_faces
# Extracted and transformed 148 frames from video: id49_id55_0006_faces
# Extracted and transformed 148 frames from video: id6_id26_0001_faces
# Extracted and transformed 148 frames from video: id16_id21_0012_faces
# Extracted and transformed 148 frames from video: id24_id28_0008_faces
# Extracted and transformed 148 frames from video: id20_id37_0004_faces
# Extracted and transformed 148 frames from video: id26_id2_0000_faces
# Extracted and transformed 148 frames from video: id10_id12_0008_faces
# Extracted and transformed 148 frames from video: id10_id13_0003_faces
# Extracted and transformed 148 frames from video: id37_id21_0002_faces
# ...
# Extracted and transformed 148 frames from video: 22_10__talking_against_wall__X803B18R_faces
# Extracted and transformed 144 frames from video: 06_15__exit_phone_room__QRCD27P8_faces
# Extracted and transformed 148 frames from video: 05_16__podium_speech_happy__BY646B4R_faces
# Extracted and transformed 148 frames from video: 03_04__kitchen_pan__T04P6ELC_faces
# Extracted and transformed 148 frames from video: 20_13__outside_talking_still_laughing__LXLR1B6N_faces
# Extracted and transformed 136 frames from video: 20_21__hugging_happy__ZCB5OMEW_faces
# Extracted and transformed 148 frames from video: 10_22__kitchen_still__8YQ2EUQP_faces
# Extracted and transformed 148 frames from video: 26_25__podium_speech_happy__8LPKLIRG_faces
# Extracted and transformed 148 frames from video: 02_07__outside_talking_pan_laughing__O4SXNLRL_faces
# Extracted and transformed 148 frames from video: 26_20__podium_speech_happy__01OJA93K_faces
# Extracted and transformed 148 frames from video: 18_14__walking_outside_cafe_disgusted__0YRBHIKG_faces
# Extracted and transformed 120 frames from video: 04_02__secret_conversation__8CH7R4LW_faces
# Extracted and transformed 148 frames from video: 13_20__walking_down_indoor_hall_disgust__EV1V4ZQV_faces
# Extracted and transformed 148 frames from video: 03_01__hugging_happy__ISF9SP4G_faces
# Extracted and transformed 148 frames from video: 04_11__exit_phone_room__60BU0X0I_faces
# Extracted and transformed 140 frames from video: 11_07__kitchen_pan__H1YF1M1B_faces
# Extracted and transformed 148 frames from video: 25_20__outside_talking_still_laughing__AMY6M1KL_faces
# Extracted and transformed 148 frames from video: 26_18__talking_against_wall__UMEX6HWU_faces
# Extracted and transformed 144 frames from video: 28_08__secret_conversation__5DCAESDA_faces
# Extracted and transformed 148 frames from video: 03_06__podium_speech_happy__KIWCEATU_faces
# Extracted and transformed 148 frames from video: 12_06__talking_against_wall__3K21NFNM_faces
# Extracted and transformed 140 frames from video: 19_24__outside_talking_pan_laughing__OF8LF68K_faces
# Extracted and transformed 148 frames from video: 06_15__kitchen_still__QRCD27P8_faces
# Extracted and transformed 148 frames from video: 03_07__walking_down_indoor_hall_disgust__F0YYEA5W_faces
# Extracted and transformed 148 frames from video: 12_26__talking_against_wall__FWFQ5YB8_faces
# Extracted and transformed 148 frames from video: 24_19__exit_phone_room__59PN7WZ2_faces
# Extracted and transformed 148 frames from video: 20_18__walking_outside_cafe_disgusted__8BMQOD7S_faces
# Extracted and transformed 148 frames from video: 07_02__walking_down_street_outside_angry__O4SXNLRL_faces
# Extracted and transformed 140 frames from video: 02_01__secret_conversation__YVGY8LOK_faces
# Extracted and transformed 148 frames from video: 09_21__walking_down_street_outside_angry__Z8H2TRCI_faces
# Extracted and transformed 148 frames from video: 01_20__outside_talking_still_laughing__FW94AIMJ_faces
# Extracted and transformed 148 frames from video: 20_25__outside_talking_still_laughing__FZHCQNKV_faces
# Extracted and transformed 148 frames from video: 03_07__podium_speech_happy__6PHZRQ4H_faces
# Extracted and transformed 148 frames from video: 12_18__hugging_happy__IKH1LBBY_faces
# Extracted and transformed 148 frames from video: 13_12__outside_talking_still_laughing__2TM4IFSF_faces
# Extracted and transformed 148 frames from video: 15_27__outside_talking_still_laughing__WZ4MLUAV_faces
# Extracted and transformed 148 frames from video: 13_12__talking_against_wall__2TM4IFSF_faces
# Extracted and transformed 148 frames from video: 20_07__outside_talking_still_laughing__5VT4USF9_faces
# Extracted and transformed 148 frames from video: 07_15__walk_down_hall_angry__NYPO7U50_faces
# Extracted and transformed 148 frames from video: 13_14__outside_talking_pan_laughing__KMQ3AW6A_faces
# Extracted and transformed 148 frames from video: 23_19__walking_and_outside_surprised__F7U8UY7V_faces
# Extracted and transformed 148 frames from video: 23_22__kitchen_still__10R2HRAU_faces
# Extracted and transformed 148 frames from video: 01_02__walking_down_indoor_hall_disgust__YVGY8LOK_faces
# Extracted and transformed 148 frames from video: 09_18__outside_talking_still_laughing__3VP8836C_faces
# Extracted and transformed 148 frames from video: 23_24__kitchen_still__MDSDXSNU_faces
# Extracted and transformed 148 frames from video: 01_20__meeting_serious__D8GWGO2A_faces
# Extracted and transformed 148 frames from video: 03_12__kitchen_pan__D7G6YJON_faces
# Extracted and transformed 136 frames from video: 19_23__kitchen_pan__WHQ1229T_faces
# Extracted and transformed 148 frames from video: 20_13__kitchen_still__NJEO6L5O_faces
# Extracted and transformed 148 frames from video: 01_09__talking_angry_couch__P70H1JB0_faces
# Extracted and transformed 144 frames from video: 07_20__outside_talking_pan_laughing__KV6Q7D6C_faces
# Extracted and transformed 148 frames from video: 03_07__secret_conversation__9NVYPOMN_faces
# Extracted and transformed 148 frames from video: 02_13__meeting_serious__CP5HFV3K_faces
# Extracted and transformed 148 frames from video: 03_21__kitchen_pan__YCSEBZO4_faces
# Extracted and transformed 148 frames from video: 23_22__kitchen_still__X2ZN5Q31_faces
# Extracted and transformed 148 frames from video: 03_18__podium_speech_happy__22UBC0BS_faces
# Extracted and transformed 148 frames from video: 04_01__talking_angry_couch__0XUW13RW_faces
# Extracted and transformed 36 frames from video: 02_14__secret_conversation__3IUBEKCT_faces
# Extracted and transformed 148 frames from video: 26_13__podium_speech_happy__U5ELHUN5_faces
# Extracted and transformed 148 frames from video: 01_11__meeting_serious__FAFWDR4W_faces
# Extracted and transformed 120 frames from video: 20_03__hugging_happy__Z6V05FXO_faces
# Extracted and transformed 148 frames from video: 06_02__walking_down_indoor_hall_disgust__GH8TGTBS_faces
# Extracted and transformed 148 frames from video: 26_25__talking_angry_couch__GJT740J9_faces
# Extracted and transformed 148 frames from video: 22_23__walking_and_outside_surprised__NUTQ0HJ5_faces
# Extracted and transformed 148 frames from video: 06_07__outside_talking_still_laughing__NMGYPBXE_faces
# Extracted and transformed 140 frames from video: 12_21__kitchen_pan__ME7E3R1D_faces
# Extracted and transformed 148 frames from video: 05_16__kitchen_still__053HPS1G_faces
# Extracted and transformed 148 frames from video: 14_21__exit_phone_room__IRKML4J0_faces
# Extracted and transformed 148 frames from video: 15_02__exit_phone_room__HTG660F8_faces
# Extracted and transformed 148 frames from video: 27_25__hugging_happy__1KU29EUL_faces
# Extracted and transformed 148 frames from video: 15_03__outside_talking_still_laughing__Y11NT1YX_faces
# Extracted and transformed 144 frames from video: 07_04__hugging_happy__ITC0C48B_faces
# Extracted and transformed 148 frames from video: 14_27__outside_talking_pan_laughing__0KSONKQ2_faces
# Extracted and transformed 148 frames from video: 19_23__walking_outside_cafe_disgusted__WHQ1229T_faces
# Extracted and transformed 148 frames from video: 14_13__kitchen_still__KMQ3AW6A_faces
# Extracted and transformed 148 frames from video: 06_12__walking_down_street_outside_angry__3K21NFNM_faces
# Extracted and transformed 136 frames from video: 21_09__hugging_happy__Z8H2TRCI_faces
# Extracted and transformed 148 frames from video: 12_06__walking_and_outside_surprised__3K21NFNM_faces
# Extracted and transformed 148 frames from video: 03_04__talking_angry_couch__T04P6ELC_faces
# Extracted and transformed 148 frames from video: 21_14__podium_speech_happy__N0WM4GSV_faces
# Extracted and transformed 148 frames from video: 13_26__talking_against_wall__WK3NZ3UV_faces
# Extracted and transformed 148 frames from video: 01_21__outside_talking_pan_laughing__03X7CELV_faces
# Extracted and transformed 148 frames from video: 12_07__outside_talking_pan_laughing__0VN0A2T3_faces
# Extracted and transformed 148 frames from video: 28_08__exit_phone_room__KXO8S7OP_faces
# Extracted and transformed 148 frames from video: 14_03__walking_outside_cafe_disgusted__PLCQJM81_faces
# Extracted and transformed 148 frames from video: 23_19__podium_speech_happy__D1K19NUP_faces
# Extracted and transformed 148 frames from video: 02_12__podium_speech_happy__9D2ZHEKW_faces
# Extracted and transformed 148 frames from video: 02_15__outside_talking_pan_laughing__SB6PMCO0_faces
# Extracted and transformed 100 frames from video: 21_02__kitchen_pan__Z0XHPQAR_faces
# Extracted and transformed 148 frames from video: 03_13__meeting_serious__GBYWJW06_faces
# Extracted and transformed 148 frames from video: 02_15__podium_speech_happy__I8G2LWD1_faces
# Extracted and transformed 132 frames from video: 13_09__hugging_happy__LPT427RY_faces
# Extracted and transformed 148 frames from video: 26_14__exit_phone_room__SU8SAHTT_faces
# Extracted and transformed 148 frames from video: 25_21__walking_outside_cafe_disgusted__NFBISHIN_faces
# Extracted and transformed 148 frames from video: 21_11__walk_down_hall_angry__USLHUQDI_faces
# Extracted and transformed 148 frames from video: 15_12__walking_and_outside_surprised__N0SRODQD_faces
# Extracted and transformed 148 frames from video: 14_27__exit_phone_room__0KSONKQ2_faces
# Extracted and transformed 144 frames from video: 18_27__outside_talking_pan_laughing__NYHE8D0J_faces
# Extracted and transformed 148 frames from video: 07_03__walk_down_hall_angry__6PHZRQ4H_faces
# Extracted and transformed 148 frames from video: 24_19__podium_speech_happy__OF8LF68K_faces
# Extracted and transformed 148 frames from video: 08_16__exit_phone_room__8Q7JCS95_faces
# Extracted and transformed 148 frames from video: 06_27__walking_and_outside_surprised__VN14WY2N_faces
# Extracted and transformed 148 frames from video: 11_07__kitchen_still__R7R86Z62_faces
# Extracted and transformed 148 frames from video: 20_15__outside_talking_still_laughing__99NHTFBM_faces
# Extracted and transformed 140 frames from video: 07_21__hugging_happy__CRGVSDBI_faces
# Extracted and transformed 148 frames from video: 15_07__kitchen_still__9Z2MLKVX_faces
# Extracted and transformed 148 frames from video: 13_25__walking_down_street_outside_angry__IW9OFVMG_faces
# Extracted and transformed 140 frames from video: 20_14__talking_angry_couch__R7SPX6OK_faces
# Extracted and transformed 148 frames from video: 07_02__talking_against_wall__U7DEOZNV_faces
# Extracted and transformed 148 frames from video: 18_26__talking_against_wall__AI94QW74_faces
# Extracted and transformed 148 frames from video: 28_08__kitchen_still__HIOU8Z8I_faces
# Extracted and transformed 148 frames from video: 07_21__kitchen_still__MKU99DVX_faces
# Extracted and transformed 148 frames from video: 23_22__outside_talking_still_laughing__W9MT3Q5K_faces
# Extracted and transformed 148 frames from video: 20_12__walk_down_hall_angry__B0X1CGG2_faces
# Extracted and transformed 148 frames from video: 02_25__walking_and_outside_surprised__Z7FQ69VP_faces
# Extracted and transformed 136 frames from video: 25_20__exit_phone_room__FZHCQNKV_faces
# Extracted and transformed 148 frames from video: 01_26__outside_talking_pan_laughing__ZMEJ535O_faces
# Extracted and transformed 148 frames from video: 06_03__talking_angry_couch__83ABVHC3_faces
# Extracted and transformed 148 frames from video: 09_03__talking_against_wall__8DTEGQ54_faces
# Extracted and transformed 148 frames from video: 26_25__outside_talking_still_laughing__7ZRKCFMS_faces
# Extracted and transformed 148 frames from video: 04_01__walking_outside_cafe_disgusted__0XUW13RW_faces
# Extracted and transformed 136 frames from video: 26_14__secret_conversation__SU8SAHTT_faces
# Extracted and transformed 140 frames from video: 07_14__hugging_happy__P9QFO50U_faces
# Extracted and transformed 148 frames from video: 12_13__talking_angry_couch__WCPCP2TD_faces
# Extracted and transformed 148 frames from video: 20_25__outside_talking_still_laughing__M86GQTHK_faces
# Extracted and transformed 144 frames from video: 03_13__secret_conversation__GBYWJW06_faces
# Extracted and transformed 148 frames from video: 07_04__kitchen_still__M2NBCLFR_faces
# Extracted and transformed 124 frames from video: 20_14__hugging_happy__B014BKVO_faces
# Extracted and transformed 136 frames from video: 19_24__secret_conversation__DL7X7M6I_faces
# Extracted and transformed 132 frames from video: 16_05__hugging_happy__V7BK27TX_faces
# Extracted and transformed 144 frames from video: 09_18__kitchen_pan__3VP8836C_faces
# Extracted and transformed 136 frames from video: 11_06__outside_talking_pan_laughing__C8C4FW99_faces
# Extracted and transformed 148 frames from video: 13_14__talking_against_wall__KMQ3AW6A_faces
# Extracted and transformed 148 frames from video: 18_14__podium_speech_happy__0YRBHIKG_faces
# Extracted and transformed 148 frames from video: 07_09__walk_down_hall_angry__N9CWME71_faces
# Extracted and transformed 148 frames from video: 24_22__walk_down_hall_angry__7E3GY85F_faces
# Extracted and transformed 144 frames from video: 21_07__kitchen_still__K7KXUHMU_faces
# Extracted and transformed 148 frames from video: 12_02__walking_and_outside_surprised__9D2ZHEKW_faces
# Extracted and transformed 148 frames from video: 10_22__exit_phone_room__8YQ2EUQP_faces
# Extracted and transformed 148 frames from video: 22_23__outside_talking_pan_laughing__J671JKCH_faces
# Extracted and transformed 148 frames from video: 24_19__outside_talking_pan_laughing__LVZNRK9S_faces
# Extracted and transformed 148 frames from video: 01_04__hugging_happy__GBC7ZGDP_faces
# Extracted and transformed 148 frames from video: 02_27__outside_talking_pan_laughing__QW05XUUZ_faces
# Extracted and transformed 148 frames from video: 18_06__secret_conversation__DEA1TCLN_faces
# Extracted and transformed 108 frames from video: 21_09__kitchen_pan__Z8H2TRCI_faces
# Extracted and transformed 148 frames from video: 11_18__walking_down_street_outside_angry__PT4YKO2R_faces
# Extracted and transformed 148 frames from video: 06_26__walk_down_hall_angry__L5BVR5L9_faces
# Extracted and transformed 148 frames from video: 09_13__talking_against_wall__LPT427RY_faces
# Extracted and transformed 148 frames from video: 16_05__walking_outside_cafe_disgusted__053HPS1G_faces
# Extracted and transformed 148 frames from video: 02_15__outside_talking_pan_laughing__I8G2LWD1_faces
# Extracted and transformed 104 frames from video: 15_02__hugging_happy__SB6PMCO0_faces
# Extracted and transformed 136 frames from video: 22_10__kitchen_pan__EHARPYBT_faces
# Extracted and transformed 148 frames from video: 21_14__walking_and_outside_surprised__N0WM4GSV_faces
# Extracted and transformed 148 frames from video: 27_18__outside_talking_pan_laughing__NYHE8D0J_faces
# Extracted and transformed 96 frames from video: 25_02__secret_conversation__Z7FQ69VP_faces
# Extracted and transformed 148 frames from video: 12_13__outside_talking_pan_laughing__2TM4IFSF_faces
# Extracted and transformed 148 frames from video: 01_14__walking_outside_cafe_disgusted__01YF7VQM_faces
# Extracted and transformed 128 frames from video: 21_15__kitchen_pan__87WSBJP3_faces
# Extracted and transformed 148 frames from video: 12_15__walking_down_street_outside_angry__N0SRODQD_faces
# Extracted and transformed 148 frames from video: 03_07__kitchen_pan__WPT3Z2KN_faces
# Extracted and transformed 148 frames from video: 25_20__talking_against_wall__CYKLS79C_faces
# Extracted and transformed 148 frames from video: 17_08__talking_against_wall__QOX5NWIJ_faces
# Extracted and transformed 148 frames from video: 13_09__outside_talking_still_laughing__30N46VHZ_faces
# Extracted and transformed 148 frames from video: 23_19__walking_and_outside_surprised__H4SUVFTL_faces
# Extracted and transformed 136 frames from video: 26_13__kitchen_pan__U5ELHUN5_faces
# Extracted and transformed 148 frames from video: 10_22__kitchen_still__1TXK09OY_faces
# Extracted and transformed 148 frames from video: 21_14__walk_down_hall_angry__N0WM4GSV_faces
# Extracted and transformed 148 frames from video: 03_06__podium_speech_happy__1IXGY2FK_faces
# Extracted and transformed 148 frames from video: 21_14__podium_speech_happy__IRKML4J0_faces
# Extracted and transformed 140 frames from video: 25_06__outside_talking_pan_laughing__MI9BDQ7M_faces

# %% [markdown]
# ## Statistics: Calculate Average Extracted Frames

# %%
import os

# Base directory where the extracted frames are stored
extracted_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames'

# List of datasets and categories
datasets = ['celebdf', 'ff']
categories = ['real', 'fake']

# Function to calculate average extracted frames for each dataset and category
def calculate_average_frames(dataset, category):
    # Path to the specific dataset and category
    path = os.path.join(extracted_frames_main_dir, f"{dataset}_{category}")

    if not os.path.exists(path):
        print(f"No extracted frames found for {dataset} {category}.")
        return

    # Initialize variables to calculate the total frames and count of videos
    total_frames = 0
    video_count = 0

    # Iterate over each video directory
    for video_folder in os.listdir(path):
        video_path = os.path.join(path, video_folder)

        # Check if it is a directory
        if os.path.isdir(video_path):
            # Count the number of frames in the video folder
            frame_count = len([f for f in os.listdir(video_path) if f.endswith('.jpg')])
            total_frames += frame_count
            video_count += 1

    # Calculate the average number of frames
    if video_count > 0:
        average_frames = total_frames / video_count
        print(f"Average extracted frames for {dataset} {category}: {average_frames:.2f}")
    else:
        print(f"No valid videos found for {dataset} {category}.")

# Iterate through each dataset and category
for dataset in datasets:
    for category in categories:
        calculate_average_frames(dataset, category)
# Out:
# Average extracted frames for celebdf real: 146.99
# Average extracted frames for celebdf fake: 147.89
# Average extracted frames for ff real: 135.20
# Average extracted frames for ff fake: 143.45

# %% [markdown]
# ## Statistics: Calculate Average Extracted Transformed Frames

# %%
import os

# Base directory where the transformed frames are stored
transformed_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames/transformed'

# Define paths for the datasets
datasets = {
    'celebdf_real': os.path.join(transformed_frames_main_dir, 'celebdf_real'),
    'celebdf_fake': os.path.join(transformed_frames_main_dir, 'celebdf_fake'),
    'ff_real': os.path.join(transformed_frames_main_dir, 'ff_real'),
    'ff_fake': os.path.join(transformed_frames_main_dir, 'ff_fake')
}

# Function to calculate the average extracted frames for each dataset and category
def calculate_average_frames(dataset_name, category_path):
    if not os.path.exists(category_path):
        print(f"No extracted frames found for {dataset_name}.")
        return

    # Initialize variables to calculate the total frames and count of videos
    total_frames = 0
    video_count = 0

    # Iterate over each video directory
    for video_folder in os.listdir(category_path):
        video_folder_path = os.path.join(category_path, video_folder)

        # Check if it is a directory
        if os.path.isdir(video_folder_path):
            # Count the number of frames in the video folder
            frame_count = len([f for f in os.listdir(video_folder_path) if f.endswith('.jpg')])
            total_frames += frame_count
            video_count += 1

    # Calculate the average number of frames
    if video_count > 0:
        average_frames = total_frames / video_count
        print(f"Average extracted frames for {dataset_name.replace('_', ' ') } transformed: {average_frames:.2f}")
    else:
        print(f"No valid videos found for {dataset_name}.")

# Iterate through each dataset and category to calculate the average frames
for dataset_name, dataset_path in datasets.items():
    calculate_average_frames(dataset_name, dataset_path)
# Out:
# Average extracted frames for celebdf real transformed: 146.99
# Average extracted frames for celebdf fake transformed: 147.89
# Average extracted frames for ff real transformed: 135.20
# Average extracted frames for ff fake transformed: 143.45

# %% [markdown]
# ##  Statistics: Calculate the Mode of Extracted Transformed Frames

# %%
import os
from collections import Counter

# Base directory where the transformed frames are stored
transformed_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames/transformed'

# Define paths for the datasets
datasets = {
    'celebdf_real': os.path.join(transformed_frames_main_dir, 'celebdf_real'),
    'celebdf_fake': os.path.join(transformed_frames_main_dir, 'celebdf_fake'),
    'ff_real': os.path.join(transformed_frames_main_dir, 'ff_real'),
    'ff_fake': os.path.join(transformed_frames_main_dir, 'ff_fake')
}

# Function to calculate the mode of extracted frames for each dataset
def calculate_mode_frames(dataset_name, dataset_path):
    if not os.path.exists(dataset_path):
        print(f"No extracted frames found for {dataset_name}.")
        return

    # List to store the frame counts of all videos
    frame_counts = []

    # Iterate over each video directory
    for video_folder in os.listdir(dataset_path):
        video_path = os.path.join(dataset_path, video_folder)

        # Check if it is a directory
        if os.path.isdir(video_path):
            # Count the number of frames in the video folder
            frame_count = len([f for f in os.listdir(video_path) if f.endswith('.jpg')])
            frame_counts.append(frame_count)

    # Calculate the mode of frame counts
    if frame_counts:
        frame_count_counter = Counter(frame_counts)
        mode_frame_count = frame_count_counter.most_common(1)  # Get the most common frame count

        # Display the mode and its frequency
        mode_value, frequency = mode_frame_count[0]
        print(f"Mode of extracted frames for {dataset_name}: {mode_value} frames (Frequency: {frequency})")
    else:
        print(f"No valid videos found for {dataset_name}.")

# Iterate through each dataset
for dataset_name, dataset_path in datasets.items():
    calculate_mode_frames(dataset_name, dataset_path)
# Out:
# Mode of extracted frames for celebdf_real: 148 frames (Frequency: 566)
# Mode of extracted frames for celebdf_fake: 148 frames (Frequency: 581)
# Mode of extracted frames for ff_real: 148 frames (Frequency: 201)
# Mode of extracted frames for ff_fake: 148 frames (Frequency: 300)

# %% [markdown]
# ##  Statistics: Calculate the Mode of Extracted Frames

# %%
import os
from collections import Counter

# Base directory where the transformed frames are stored
extracted_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames'

# Define paths for the datasets
datasets = {
    'celebdf_real': os.path.join(extracted_frames_main_dir, 'celebdf_real'),
    'celebdf_fake': os.path.join(extracted_frames_main_dir, 'celebdf_fake'),
    'ff_real': os.path.join(extracted_frames_main_dir, 'ff_real'),
    'ff_fake': os.path.join(extracted_frames_main_dir, 'ff_fake')
}

# Function to calculate the mode of extracted frames for each dataset
def calculate_mode_frames(dataset, path):
    if not os.path.exists(path):
        print(f"No extracted frames found at path: {path}")
        return

    # List to store the frame counts of all videos
    frame_counts = []

    # Iterate over each video directory
    for video_folder in os.listdir(path):
        video_path = os.path.join(path, video_folder)

        # Check if it is a directory
        if os.path.isdir(video_path):
            # Count the number of frames in the video folder
            frame_count = len([f for f in os.listdir(video_path) if f.endswith('.jpg')])
            
            
            
            frame_counts.append(frame_count)

    # Calculate the mode of frame counts
    if frame_counts:
        frame_count_counter = Counter(frame_counts)
        mode_frame_count = frame_count_counter.most_common(1)  # Get the most common frame count

        # Display the mode and its frequency
        mode_value, frequency = mode_frame_count[0]
        print(f"Mode of extracted frames for {dataset}: {mode_value} frames (Frequency: {frequency})")
    else:
        print(f"No valid videos found in {dataset} directory.")

# Iterate through each dataset and category path
for dataset, path in datasets.items():
    calculate_mode_frames(dataset, path)
# Out:
# Mode of extracted frames for celebdf_real: 148 frames (Frequency: 566)
# Mode of extracted frames for celebdf_fake: 148 frames (Frequency: 581)
# Mode of extracted frames for ff_real: 148 frames (Frequency: 201)
# Mode of extracted frames for ff_fake: 148 frames (Frequency: 300)

# %% [markdown]
# ## Statistics: Calculate the extracted frames (non-transformed)

# %%
import os

# Base directory where the extracted frames are stored
extracted_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames'

# Define paths for the datasets
datasets = {
    'celebdf_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf real',
    'celebdf_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/celebdf fake',
    'ff_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real',
    'ff_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake'
}

# Function to count extracted frames for each dataset and category
def count_extracted_frames(category_path):
    total_frames = 0
    video_count = 0

    # Iterate over each video directory in the dataset category
    for video_folder in os.listdir(category_path):
        video_folder_path = os.path.join(category_path, video_folder)

        if os.path.isdir(video_folder_path):
            # Count the number of frames (i.e., .jpg files) in the video folder
            frame_count = len([f for f in os.listdir(video_folder_path) if f.endswith('.jpg')])
            total_frames += frame_count
            video_count += 1

    return total_frames

# Iterate through each dataset and category to count extracted frames
for dataset_name, dataset_path in datasets.items():
    # Define the path to the extracted frames directory for each dataset
    category_path = os.path.join(extracted_frames_main_dir, dataset_name)

    # Count the extracted frames for the current dataset category
    total_frames = count_extracted_frames(category_path)

    # Print the total frames for each dataset category
    print(f"{dataset_name.replace('_', ' ')}: {total_frames} frames")
# Out:
# celebdf real: 86580 frames
# celebdf fake: 87256 frames
# ff real: 48944 frames
# ff fake: 52216 frames

# %% [markdown]
# ## Statistics: Calculate the extracted frames (transformed dataset)

# %%
import os

# Base directory where the extracted frames are stored
extracted_frames_main_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted frames/transformed'

# Define paths for the datasets
datasets = {
    'celebdf_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/celebdf_real',
    'celebdf_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/celebdf_fake',
    'ff_real': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/ff_real',
    'ff_fake': '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/transformed/ff_fake'
}

# Function to count extracted frames for each dataset and category
def count_extracted_frames(category_path):
    total_frames = 0
    video_count = 0

    # Iterate over each video directory in the dataset category
    for video_folder in os.listdir(category_path):
        video_folder_path = os.path.join(category_path, video_folder)

        if os.path.isdir(video_folder_path):
            # Count the number of frames (i.e., .jpg files) in the video folder
            frame_count = len([f for f in os.listdir(video_folder_path) if f.endswith('.jpg')])
            total_frames += frame_count
            video_count += 1

    return total_frames

# Iterate through each dataset and category to count extracted frames
for dataset_name, dataset_path in datasets.items():
    # Define the path to the extracted frames directory for each dataset
    category_path = os.path.join(extracted_frames_main_dir, dataset_name)

    # Count the extracted frames for the current dataset category
    total_frames = count_extracted_frames(category_path)

    # Print the total frames for each dataset category
    print(f"{dataset_name.replace('_', ' ')}: {total_frames} frames")
# Out:
# celebdf real: 86580 frames
# celebdf fake: 87256 frames
# ff real: 48944 frames
# ff fake: 52216 frames
