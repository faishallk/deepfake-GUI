# %% [markdown]
# # 10 epoch

# %% [markdown]
# ## Accuracy

# %%
celeb_df_resnextonly_lr00001_transformed = [0.6333, 0.7263, 0.7791, 0.8136, 0.8542, 0.8781, 0.9029, 0.9163, 0.9439, 0.9574]
celeb_df_resnextlstm_lr00001_transformed = [0.6369, 0.7452, 0.7871, 0.8196, 0.8558, 0.8832, 0.8987, 0.9185, 0.9444, 0.9545]

celeb_df_resnextonly_lr00001_notransformed = [0.7988, 0.8997, 0.9428, 0.9574, 0.9709, 0.9766, 0.9839, 0.9839, 0.9880, 0.9938]
celeb_df_resnextlstm_lr00001_notransformed = [0.8186, 0.9231, 0.9514, 0.9654, 0.9745, 0.9777, 0.9794, 0.9875, 0.9864, 0.9902]

celeb_df_resnextonly_lr001_transformed = [0.5210, 0.5296, 0.5466, 0.5604, 0.6416, 0.7378, 0.7891, 0.8454, 0.8858, 0.9178]
celeb_df_resnextlstm_lr001_transformed = [0.4964, 0.5075, 0.4980, 0.5042, 0.5101, 0.4985, 0.4987, 0.5020, 0.5084, 0.5010]

celeb_df_resnextonly_lr001_notransformed = [0.4963, 0.4990, 0.5000, 0.4898, 0.5061, 0.5017, 0.4942, 0.4981, 0.4935, 0.4970]
celeb_df_resnextlstm_lr001_notransformed = [0.5202, 0.5259, 0.5307, 0.5014, 0.5030, 0.4950, 0.4923, 0.4989, 0.4895, 0.5091]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 11))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr00001_transformed, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr00001_transformed, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr00001_notransformed, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr00001_notransformed, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr001_transformed, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr001_transformed, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr001_notransformed, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr001_notransformed, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Accuracy 10 Epochs for Celeb-DF Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loss

# %%
loss_celeb_df_resnextonly_lr00001_transformed = [0.6523, 0.5440, 0.4660, 0.4134, 0.3417, 0.2827, 0.2368, 0.2041, 0.1439, 0.1103]
loss_celeb_df_resnextlstm_lr00001_transformed = [0.6320, 0.5258, 0.4573, 0.3907, 0.3318, 0.2759, 0.2426, 0.1967, 0.1402, 0.1185]

loss_celeb_df_resnextonly_lr00001_notransformed = [0.4309, 0.2496, 0.1514, 0.1152, 0.0788, 0.0702, 0.0477, 0.0520, 0.0355, 0.0198]
loss_celeb_df_resnextlstm_lr00001_notransformed = [0.3946, 0.1915, 0.1375, 0.0959, 0.0727, 0.0642, 0.0605, 0.0373, 0.0415, 0.0324]

loss_celeb_df_resnextonly_lr001_transformed = [0.8593, 0.6907, 0.6849, 0.6764, 0.6215, 0.5350, 0.4403, 0.3518, 0.2790, 0.1991]
loss_celeb_df_resnextlstm_lr001_transformed = [0.7707, 0.7594, 0.7550, 0.7455, 0.7565, 0.7373, 0.7648, 0.7576, 0.7626, 0.7543]

loss_celeb_df_resnextonly_lr001_notransformed = [0.7459, 0.7409, 0.7294, 0.7539, 0.7891, 0.7386, 0.7449, 0.7448, 0.7518, 0.7358]
loss_celeb_df_resnextlstm_lr001_notransformed = [0.7527, 0.7441, 0.7338, 0.7537, 0.7449, 0.7544, 0.7297, 0.7478, 0.7523, 0.7466]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 11))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr00001_transformed, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr00001_transformed, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr00001_notransformed, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr00001_notransformed, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr001_transformed, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr001_transformed, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr001_notransformed, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr001_notransformed, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Loss 10 Epochs for Celeb-DF Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# # 15 EPOCH

# %% [markdown]
# ## Accuracy

# %%
celeb_df_resnextonly_lr00001_transformed15 = [0.6291, 0.7239, 0.7722, 0.8114, 0.8321, 0.8652, 0.8902, 0.9114, 0.9253, 0.9425, 0.9530, 0.9650, 0.9685, 0.9732, 0.9802]
celeb_df_resnextlstm_lr00001_transformed15 = [0.6541, 0.7483, 0.7951, 0.8212, 0.8579, 0.8843, 0.9020, 0.9131, 0.9359, 0.9472, 0.9594, 0.9660, 0.9715, 0.9738, 0.9791]

celeb_df_resnextonly_lr00001_notransformed15 = [0.8000, 0.9128, 0.9456, 0.9536, 0.9684, 0.9779, 0.9875, 0.9817, 0.9844, 0.9880, 0.9902, 0.9882, 0.9943, 0.9913, 0.9914]
celeb_df_resnextlstm_lr00001_notransformed15 = [0.8260, 0.9250, 0.9493, 0.9654, 0.9781, 0.9826, 0.9833, 0.9878, 0.9857, 0.9878, 0.9893, 0.9900, 0.9927, 0.9907, 0.9877]

celeb_df_resnextonly_lr001_transformed15 = [0.5274, 0.5502, 0.5659, 0.6126, 0.6730, 0.7380, 0.8006, 0.8570, 0.8984, 0.9213, 0.9441, 0.9637, 0.9630, 0.9683, 0.9746]
celeb_df_resnextlstm_lr001_transformed15 = [0.5006, 0.5010, 0.5154, 0.4990, 0.5038, 0.4952, 0.5110, 0.5008, 0.4985, 0.4908, 0.5054, 0.5010, 0.5071, 0.4949, 0.4990]

celeb_df_resnextonly_lr001_notransformed15 = [0.5136, 0.4989, 0.4976, 0.5235, 0.4964, 0.4967, 0.4889, 0.5075, 0.4992, 0.5017, 0.4898, 0.4964, 0.5108, 0.5080, 0.5047]
celeb_df_resnextlstm_lr001_notransformed15 = [0.5329, 0.5210, 0.5010, 0.4964, 0.4967, 0.4997, 0.4958, 0.5100, 0.5030, 0.5030, 0.4975, 0.4972, 0.4956, 0.5006, 0.4994]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 16))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr00001_transformed15, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr00001_transformed15, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr00001_notransformed15, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr00001_notransformed15, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr001_transformed15, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr001_transformed15, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr001_notransformed15, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr001_notransformed15, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Accuracy 15 Epochs for Celeb-DF Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loss

# %%
loss_celeb_df_resnextonly_lr00001_transformed15 = [0.6550, 0.5510, 0.4778, 0.4209, 0.3726, 0.3179, 0.2624, 0.2181, 0.1791, 0.1506, 0.1187, 0.0950, 0.0862, 0.0725, 0.0615]
loss_celeb_df_resnextlstm_lr00001_transformed15 = [0.6229, 0.5156, 0.4443, 0.3916, 0.3311, 0.2729, 0.2338, 0.2150, 0.1601, 0.1389, 0.1014, 0.0916, 0.0745, 0.0671, 0.0553]

loss_celeb_df_resnextonly_lr00001_notransformed15 = [0.4243, 0.2212, 0.1412, 0.1253, 0.0836, 0.0605, 0.0415, 0.0496, 0.0510, 0.0348, 0.0261, 0.0391, 0.0183, 0.0244, 0.0278]
loss_celeb_df_resnextlstm_lr00001_notransformed15 = [0.3768, 0.1873, 0.1357, 0.0959, 0.0664, 0.0539, 0.0502, 0.0367, 0.0436, 0.0380, 0.0330, 0.0318, 0.0238, 0.0314, 0.0366]

loss_celeb_df_resnextonly_lr001_transformed15 = [0.8583, 0.6822, 0.6782, 0.6526, 0.6003, 0.5200, 0.4272, 0.3248, 0.2440, 0.1909, 0.1433, 0.1048, 0.0975, 0.0873, 0.0669]
loss_celeb_df_resnextlstm_lr001_transformed15 = [0.7627, 0.7677, 0.7454, 0.7565, 0.7598, 0.7838, 0.7415, 0.7485, 0.7377, 0.7553, 0.7410, 0.7380, 0.7613, 0.7590, 0.7569]

loss_celeb_df_resnextonly_lr001_notransformed15 = [0.7755, 0.7616, 0.7568, 0.7687, 0.7595, 0.7409, 0.7598, 0.7784, 0.7770, 0.7646, 0.7943, 0.7801, 0.7757, 0.7584, 0.7703]
loss_celeb_df_resnextlstm_lr001_notransformed15 = [0.7477, 0.7366, 0.7902, 0.7491, 0.7615, 0.8071, 0.7742, 0.7614, 0.7584, 0.7429, 0.7619, 0.7499, 0.7941, 0.7556, 0.7823]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 16))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr00001_transformed15, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr00001_transformed15, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr00001_notransformed15, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr00001_notransformed15, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr001_transformed15, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr001_transformed15, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr001_notransformed15, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr001_notransformed15, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Loss 15 Epochs for Celeb-DF Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# # 20 Epoch

# %% [markdown]
# ## accuracy

# %%
celeb_df_resnextonly_lr00001_transformed20 = [0.6349, 0.7179, 0.7613, 0.8015, 0.8277, 0.8505, 0.8787, 0.8948, 0.9154, 0.9302, 0.9544, 0.9562, 0.9643, 0.9730, 0.9771, 0.9774, 0.9843, 0.9846, 0.9855, 0.9850]
celeb_df_resnextlstm_lr00001_transformed20 = [0.6381, 0.7483, 0.7974, 0.8261, 0.8674, 0.8923, 0.9093, 0.9280, 0.9446, 0.9490, 0.9616, 0.9759, 0.9768, 0.9792, 0.9802, 0.9838, 0.9861, 0.9890, 0.9904, 0.9887]

celeb_df_resnextonly_lr00001_notransformed20 = [0.7887, 0.8990, 0.9348, 0.9585, 0.9702, 0.9776, 0.9802, 0.9864, 0.9903, 0.9885, 0.9855, 0.9938, 0.9899, 0.9939, 0.9885, 0.9920, 0.9935, 0.9934, 0.9940, 0.9935]
celeb_df_resnextlstm_lr00001_notransformed20 = [0.8187, 0.9404, 0.9590, 0.9759, 0.9747, 0.9862, 0.9839, 0.9877, 0.9880, 0.9914, 0.9925, 0.9899, 0.9932, 0.9943, 0.9956, 0.9866, 0.9971, 0.9916, 0.9942, 0.9961]

celeb_df_resnextonly_lr001_transformed20 = [0.5203, 0.5660, 0.6070, 0.6353, 0.6960, 0.7508, 0.8044, 0.8403, 0.8736, 0.9042, 0.9230, 0.9387, 0.9485, 0.9606, 0.9648, 0.9693, 0.9670, 0.9774, 0.9814, 0.9796]
celeb_df_resnextlstm_lr001_transformed20 = [0.4989, 0.4924, 0.4995, 0.5017, 0.4978, 0.5014, 0.4948, 0.5032, 0.4991, 0.4950, 0.5004, 0.4994, 0.5045, 0.4976, 0.4986, 0.4899, 0.5106, 0.4991, 0.5042, 0.4971]

celeb_df_resnextonly_lr001_notransformed20 = [0.4989, 0.4924, 0.4995, 0.5017, 0.4978, 0.5014, 0.4948, 0.5032, 0.4991, 0.4950, 0.5004, 0.4994, 0.5045, 0.4976, 0.4986, 0.4899, 0.5106, 0.4991, 0.5042, 0.4971]
celeb_df_resnextlstm_lr001_notransformed20 = [0.5203, 0.5149, 0.5050, 0.4981, 0.4986, 0.5029, 0.4931, 0.5075, 0.4997, 0.5044, 0.4956, 0.4970, 0.5071, 0.4909, 0.5018, 0.5105, 0.5008, 0.4920, 0.5011, 0.5086]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 21))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr00001_transformed20, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr00001_transformed20, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr00001_notransformed20, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr00001_notransformed20, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr001_transformed20, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr001_transformed20, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=celeb_df_resnextonly_lr001_notransformed20, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=celeb_df_resnextlstm_lr001_notransformed20, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Accuracy 20 Epochs for Celeb-DF Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loss

# %%
loss_celeb_df_resnextonly_lr00001_transformed20 = [0.6502, 0.5602, 0.4862, 0.4301, 0.3891, 0.3358, 0.2858, 0.2450, 0.2097, 0.1712, 0.1235, 0.1098, 0.0977, 0.0762, 0.0625, 0.0645, 0.0430, 0.0457, 0.0425, 0.0422]
loss_celeb_df_resnextlstm_lr00001_transformed20 = [0.6295, 0.5118, 0.4381, 0.3765, 0.3155, 0.2506, 0.2187, 0.1839, 0.1471, 0.1350, 0.0980, 0.0691, 0.0633, 0.0614, 0.0583, 0.0520, 0.0446, 0.0350,  0.0301, 0.0342]

loss_celeb_df_resnextonly_lr00001_notransformed20 = [0.4475, 0.2469, 0.1663, 0.1144, 0.0824, 0.0582, 0.0610, 0.0389, 0.0295, 0.0414, 0.0436, 0.0186, 0.0281, 0.0184, 0.0378, 0.0234, 0.0191, 0.0193, 0.0214, 0.0181]
loss_celeb_df_resnextlstm_lr00001_notransformed20 = [0.3893, 0.1676, 0.1180, 0.0704, 0.0677, 0.0378, 0.0484, 0.0360, 0.0379, 0.0269, 0.0233, 0.0306, 0.0212, 0.0169, 0.0193, 0.0379, 0.0096, 0.0240, 0.0166, 0.0125]

loss_celeb_df_resnextonly_lr001_transformed20 = [0.9347, 0.6798, 0.6573, 0.6363, 0.5811, 0.4973, 0.4175, 0.3571, 0.3010, 0.2325, 0.1928, 0.1518, 0.1327, 0.1100, 0.0955, 0.0873, 0.0856, 0.0634, 0.0518, 0.0581]
loss_celeb_df_resnextlstm_lr001_transformed20 = [0.7397, 0.7447, 0.7428, 0.7392, 0.7374, 0.7466, 0.7339, 0.7297, 0.7392, 0.7548, 0.7234, 0.7394, 0.7398, 0.7284, 0.7427, 0.7559, 0.7334, 0.7457, 0.7369, 0.7410]

loss_celeb_df_resnextonly_lr001_notransformed20 = [0.7397, 0.7447, 0.7428, 0.7392, 0.7374, 0.7466, 0.7339, 0.7297, 0.7392, 0.7548, 0.7234, 0.7394, 0.7398, 0.7284, 0.7427, 0.7559, 0.7334, 0.7457, 0.7369, 0.7410] 
loss_celeb_df_resnextlstm_lr001_notransformed20 = [0.7691, 0.7593, 0.7661, 0.7737, 0.7680, 0.7592, 0.7560, 0.7758, 0.7606, 0.7802, 0.7607, 0.7672, 0.7953, 0.7507, 0.7741, 0.7533, 0.7612, 0.7617, 0.7738, 0.7535]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 21))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr00001_transformed20, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr00001_transformed20, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr00001_notransformed20, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr00001_notransformed20, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr001_transformed20, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr001_transformed20, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextonly_lr001_notransformed20, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=loss_celeb_df_resnextlstm_lr001_notransformed20, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Loss 20 Epochs for Celeb-DF Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()
