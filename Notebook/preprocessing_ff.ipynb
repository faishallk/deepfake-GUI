# %% [markdown]
# # Statistics of FaceForensics++

# %%
import os
import cv2
import shutil

# %%
def calculate_video_statistics(video_folder):
    total_frame_count = 0
    total_video_length = 0
    total_video_count = 0

    for root, dirs, files in os.walk(video_folder):
        for file in files:
            if file.endswith(".mp4"):  # Assuming all video files are in mp4 format
                video_path = os.path.join(root, file)
                cap = cv2.VideoCapture(video_path)
                frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
                fps = int(cap.get(cv2.CAP_PROP_FPS))

                # Ensure FPS is not zero to avoid division by zero error
                if fps != 0:
                    video_length = frame_count / fps
                    total_frame_count += frame_count
                    total_video_length += video_length
                    total_video_count += 1
                cap.release()

    # Calculate average frames per video
    average_frame_per_video = total_frame_count / total_video_count if total_video_count != 0 else 0
    # Calculate average video length per video
    average_video_length_per_video = total_video_length / total_video_count if total_video_count != 0 else 0
    
    return total_frame_count, total_video_length, average_frame_per_video, average_video_length_per_video

def merge_video_folders(destination_folder, *folders):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    all_files = []
    for folder in folders:
        for root, dirs, files in os.walk(folder):
            for file in files:
                if file.endswith(".mp4"):
                    source_file = os.path.join(root, file)
                    destination_file = os.path.join(destination_folder, file)
                    if not os.path.exists(destination_file):
                        shutil.copy2(source_file, destination_file)
                    all_files.append(destination_file)
    return all_files

def calculate_statistics_from_file_list(file_list):
    total_frame_count = 0
    total_video_length = 0
    total_video_count = 0

    for video_path in file_list:
        cap = cv2.VideoCapture(video_path)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))

        # Ensure FPS is not zero to avoid division by zero error
        if fps != 0:
            video_length = frame_count / fps
            total_frame_count += frame_count
            total_video_length += video_length
            total_video_count += 1
        cap.release()

    # Calculate average frames per video
    average_frame_per_video = total_frame_count / total_video_count if total_video_count != 0 else 0
    # Calculate average video length per video
    average_video_length_per_video = total_video_length / total_video_count if total_video_count != 0 else 0
    
    return total_frame_count, total_video_length, average_frame_per_video, average_video_length_per_video

# %%
# Define file paths
ff_real_data = '/Users/faishalkamil/Downloads/documents skripsi/Faceforensics++/actors/c23/videos'

# Calculate statistics for each folder
ff_real_stats = calculate_video_statistics(ff_real_data)

# %%
print("Faceforensics++ Real Data:")
print("Total Frame Count:", ff_real_stats[0])
print("Total Video Length (seconds):", ff_real_stats[1])
print("Average Frames per Video:", ff_real_stats[2])
print("Average Video Length per Video (seconds):", ff_real_stats[3])
print()
# Out:
# Faceforensics++ Real Data:
# Total Frame Count: 315381
# Total Video Length (seconds): 13140.874999999998
# Average Frames per Video: 868.8181818181819
# Average Video Length per Video (seconds): 36.20075757575757

# %% [markdown]
# ## Data Preprocessing: Real Data

# %%
import os
import cv2
import face_recognition
import random

# %%
#  Define file paths
ff_real_data = '/Users/faishalkamil/Downloads/documents skripsi/Faceforensics++/actors/c23/videos'

# Define output parent directory for extracted frames
extracted_frames_output_parent_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new'

# Define subfolders for extracted data
output_folders = {
    'ff_real': os.path.join(extracted_frames_output_parent_dir, 'ff real')
    }

# %%
# Create subfolders if they don't exist
for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

# Function to extract frames from a video
def frame_extract(path):
    vidObj = cv2.VideoCapture(path)
    success = 1
    while success:
        success, image = vidObj.read()
        if success:
            yield image

# Process the frames and detect faces
def create_face_videos_in_batches(path_list, parent_out_dir, max_videos=364, batch_size=20, seed=42):
    random.seed(seed)

    for folder_path, output_folder in path_list:
        video_files = [file for file in os.listdir(folder_path) if file.endswith(".mp4")]
        random.shuffle(video_files)

        if output_folder == output_folders['ff_real']:
            video_files = video_files[:max_videos]

        total_files = len(video_files)

        for start_idx in range(0, total_files, batch_size):
            end_idx = min(start_idx + batch_size, total_files)
            batch_files = video_files[start_idx:end_idx]

            for file in batch_files:
                file_path = os.path.join(folder_path, file)
                file_name = os.path.splitext(file)[0]
                out_path = os.path.join(output_folder, f'{file_name}_faces.mp4')

                if os.path.exists(out_path):
                    print("File already exists:", out_path)
                    continue

                out = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc(*'mp4v'), 30, (256, 256))
                frames = []
                for idx, frame in enumerate(frame_extract(file_path)):
                    if idx <= 150:  # Adjust the number of frames to extract if needed
                        face_locations = face_recognition.face_locations(frame)
                        if face_locations:
                            top, right, bottom, left = face_locations[0]  # Use the first detected face
                            face_frame = frame[top:bottom, left:right]
                            face_frame = cv2.resize(face_frame, (256, 256))
                            frames.append(face_frame)
                            if len(frames) == 4:
                                for frame in frames:
                                    out.write(frame)
                                frames = []
                out.release()
                print("Processed:", out_path)

# Define video folders and their corresponding output folders
video_folders = [
    (ff_real_data, output_folders['ff_real'])
]

# Process the videos in batches
create_face_videos_in_batches(video_folders, extracted_frames_output_parent_dir,max_videos=364, batch_size=20, seed=42)
# Out:
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__meeting_serious_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__meeting_serious_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__meeting_serious_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/09__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__meeting_serious_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/26__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/27__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/19__kitchen_still_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__hugging_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__kitchen_pan_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/06__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/08__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/04__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__talking_angry_couch_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/23__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/01__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/17__walking_down_indoor_hall_disgust_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/07__walk_down_hall_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/25__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/15__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/05__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/16__walking_outside_cafe_disgusted_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/10__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/02__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/12__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/24__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/20__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__podium_speech_happy_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/22__exit_phone_room_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/18__talking_against_wall_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/13__outside_talking_pan_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/28__outside_talking_still_laughing_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/03__secret_conversation_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/14__walking_and_outside_surprised_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/21__walking_down_street_outside_angry_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff real/11__kitchen_pan_faces.mp4

# %% [markdown]
# ## Data Preprocessing: Fake Data

# %%
#  Define file paths
ff_fake_data = '/Users/faishalkamil/Downloads/documents skripsi/Faceforensics++/fake/DeepFakeDetection/c23/videos'

# Define output parent directory for extracted frames
extracted_frames_output_parent_dir = '/Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new'

# Define subfolders for extracted data
output_folders = {
    'ff_fake': os.path.join(extracted_frames_output_parent_dir, 'ff fake')
    }

# %%
# Create subfolders if they don't exist
for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

# Function to extract frames from a video
def frame_extract(path):
    vidObj = cv2.VideoCapture(path)
    success = 1
    while success:
        success, image = vidObj.read()
        if success:
            yield image

# Process the frames and detect faces
def create_face_videos_in_batches(path_list, parent_out_dir, max_videos=364, batch_size=20, seed=42):
    random.seed(seed)

    for folder_path, output_folder in path_list:
        video_files = [file for file in os.listdir(folder_path) if file.endswith(".mp4")]
        random.shuffle(video_files)

        if output_folder == output_folders['ff_fake']:
            video_files = video_files[:max_videos]

        total_files = len(video_files)

        for start_idx in range(0, total_files, batch_size):
            end_idx = min(start_idx + batch_size, total_files)
            batch_files = video_files[start_idx:end_idx]

            for file in batch_files:
                file_path = os.path.join(folder_path, file)
                file_name = os.path.splitext(file)[0]
                out_path = os.path.join(output_folder, f'{file_name}_faces.mp4')

                if os.path.exists(out_path):
                    print("File already exists:", out_path)
                    continue

                out = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc(*'mp4v'), 30, (256, 256))
                frames = []
                for idx, frame in enumerate(frame_extract(file_path)):
                    if idx <= 150:  # Adjust the number of frames to extract if needed
                        face_locations = face_recognition.face_locations(frame)
                        if face_locations:
                            top, right, bottom, left = face_locations[0]  # Use the first detected face
                            face_frame = frame[top:bottom, left:right]
                            face_frame = cv2.resize(face_frame, (256, 256))
                            frames.append(face_frame)
                            if len(frames) == 4:
                                for frame in frames:
                                    out.write(frame)
                                frames = []
                out.release()
                print("Processed:", out_path)

# Define video folders and their corresponding output folders
video_folders = [
    (ff_fake_data, output_folders['ff_fake'])
]

# %%
# Process the videos in batches
create_face_videos_in_batches(video_folders, extracted_frames_output_parent_dir,max_videos=364, batch_size=20, seed=42)
# Out:
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/23_19__walking_and_outside_surprised__H4SUVFTL_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/26_13__podium_speech_happy__U5ELHUN5_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/07_09__kitchen_still__N9CWME71_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/15_02__talking_against_wall__MZWH8ATN_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/06_07__outside_talking_still_laughing__NMGYPBXE_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/03_04__talking_angry_couch__T04P6ELC_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/03_07__kitchen_pan__WPT3Z2KN_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/20_03__hugging_happy__Z6V05FXO_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/15_03__outside_talking_still_laughing__Y11NT1YX_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/07_02__outside_talking_still_laughing__1ZE4HC06_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/03_18__talking_angry_couch__22UBC0BS_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/20_25__outside_talking_still_laughing__FZHCQNKV_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/03_14__walking_down_street_outside_angry__Q9NSXM88_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/28_16__walking_down_street_outside_angry__ZA8XJIE9_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/15_02__walking_outside_cafe_disgusted__MZWH8ATN_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/14_15__outside_talking_pan_laughing__3FRJCJ0V_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/04_15__kitchen_still__46TJ9IOJ_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/13_26__talking_against_wall__WK3NZ3UV_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/02_25__outside_talking_pan_laughing__Z7FQ69VP_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/06_15__kitchen_still__QRCD27P8_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/07_12__talking_against_wall__0VN0A2T3_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/17_08__hugging_happy__05AN86QA_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/14_18__hugging_happy__MAEROFMR_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/02_06__walking_down_indoor_hall_disgust__U6MDWIHG_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/25_26__talking_against_wall__8LPKLIRG_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/02_15__talking_angry_couch__I8G2LWD1_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/15_02__hugging_happy__SB6PMCO0_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/16_08__talking_against_wall__8Q7JCS95_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/20_13__outside_talking_still_laughing__LXLR1B6N_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/08_16__exit_phone_room__8Q7JCS95_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/03_04__kitchen_pan__T04P6ELC_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/23_22__kitchen_still__X2ZN5Q31_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/14_02__exit_phone_room__3IUBEKCT_faces.mp4
# Processed: /Users/faishalkamil/Downloads/documents skripsi/extracted raw dataset new/ff fake/13