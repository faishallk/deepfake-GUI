# %% [markdown]
# # 10 Epoch

# %% [markdown]
# ## Accuracy

# %%
ff_resnextonly_lr00001_transformed = [0.9268, 0.9372, 0.9451, 0.9599, 0.9611, 0.9720, 0.9665, 0.9698, 0.9772, 0.9783]
ff_resnextlstm_lr00001_transformed = [0.6438, 0.7622, 0.8001, 0.8373, 0.8504, 0.8736, 0.8943, 0.9056, 0.9221, 0.9381]

ff_resnextonly_lr00001_notransformed = [0.7656, 0.8737, 0.9101, 0.9341, 0.9568, 0.9617, 0.9727, 0.9791, 0.9850, 0.9860]
ff_resnextlstm_lr00001_notransformed = [0.7649, 0.8789, 0.9207, 0.9483, 0.9608, 0.9735, 0.9773, 0.9843, 0.9819, 0.9828]

ff_resnextonly_lr001_transformed = [0.6534, 0.7273, 0.7795, 0.8062, 0.8325, 0.8646, 0.8789, 0.8961, 0.8917, 0.9122]
ff_resnextlstm_lr001_transformed = [0.5059, 0.5007, 0.5057, 0.4885, 0.5079, 0.4984, 0.5068, 0.4937, 0.5005, 0.4959]

ff_resnextonly_lr001_notransformed = [0.5592, 0.6536, 0.7560, 0.8172, 0.8462, 0.8765, 0.9040, 0.9329, 0.9371, 0.9466]
ff_resnextlstm_lr001_notransformed = [0.5164, 0.5116, 0.4917, 0.4920, 0.5018, 0.4968, 0.5010, 0.5069, 0.4891, 0.4951]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 11))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=ff_resnextonly_lr00001_transformed, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr00001_transformed, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=ff_resnextonly_lr00001_notransformed, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr00001_notransformed, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=ff_resnextonly_lr001_transformed, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr001_transformed, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=ff_resnextonly_lr001_notransformed, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr001_notransformed, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Accuracy 10 Epochs for FaceForensics++ Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loss

# %%
loss_ff_resnextonly_lr00001_transformed = [0.1742, 0.1492, 0.1372, 0.0992, 0.1065, 0.0772, 0.0840, 0.0784, 0.0595, 0.0574]
loss_ff_resnextlstm_lr00001_transformed = [0.6236, 0.4992, 0.4310, 0.3623, 0.3249, 0.2842, 0.2415, 0.2143, 0.1894, 0.1525]

loss_ff_resnextonly_lr00001_notransformed = [0.4793, 0.3011, 0.2205, 0.1752, 0.1149, 0.1040, 0.0702, 0.0586, 0.0454, 0.0407]
loss_ff_resnextlstm_lr00001_notransformed = [0.4693, 0.2824, 0.1939, 0.1289, 0.1018, 0.0686, 0.0633, 0.0410, 0.0470, 0.0502]

loss_ff_resnextonly_lr001_transformed = [0.6315, 0.5470, 0.4665, 0.4261, 0.3726, 0.3165, 0.2760, 0.2482, 0.2448, 0.2128]
loss_ff_resnextlstm_lr001_transformed = [0.7659, 0.7489, 0.7445, 0.7539, 0.7674, 0.7435, 0.7636, 0.7508, 0.7647, 0.7491]

loss_ff_resnextonly_lr001_notransformed = [0.8224, 0.6151, 0.4942, 0.4078, 0.3509, 0.2943, 0.2344, 0.1698, 0.1606, 0.1378]
loss_ff_resnextlstm_lr001_notransformed = [0.7629, 0.7474, 0.7683, 0.7612, 0.7570, 0.7664, 0.7704, 0.7597, 0.7610, 0.7825]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 11))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr00001_transformed, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr00001_transformed, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr00001_notransformed, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr00001_notransformed, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr001_transformed, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr001_transformed, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr001_notransformed, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr001_notransformed, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Loss 10 Epochs for FaceForensics++ Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# # 15 Epoch

# %% [markdown]
# ## Accuracy

# %%
ff_resnextonly_lr00001_transformed15 = [0.6490, 0.7288, 0.7848, 0.8148, 0.8521, 0.8678, 0.8799, 0.8972, 0.9153, 0.9323, 0.9465, 0.9607, 0.9617, 0.9638, 0.9701]
ff_resnextlstm_lr00001_transformed15 = [0.6838, 0.7768, 0.8032, 0.8353, 0.8605, 0.8753, 0.8833, 0.9056, 0.9198, 0.9301, 0.9387, 0.9436, 0.9590, 0.9627, 0.9684]

ff_resnextonly_lr00001_notransformed15 = [0.7653, 0.8593, 0.9023, 0.9295, 0.9567, 0.9708, 0.9750, 0.9784, 0.9847, 0.9818, 0.9853, 0.9886, 0.9858, 0.9877, 0.9895]
ff_resnextlstm_lr00001_notransformed15 = [0.7684, 0.8817, 0.9114, 0.9420, 0.9630, 0.9703, 0.9774, 0.9835, 0.9865, 0.9833, 0.9885, 0.9874, 0.9892, 0.9937, 0.9906]

ff_resnextonly_lr001_transformed15 = [0.6030, 0.7056, 0.7435, 0.7894, 0.8179, 0.8477, 0.8708, 0.8845, 0.9101, 0.9255, 0.9402, 0.9505, 0.9554, 0.9598, 0.9689]
ff_resnextlstm_lr001_transformed15 = [0.5002, 0.4977, 0.4975, 0.4927, 0.4986, 0.5002, 0.4983, 0.5197, 0.5015, 0.5014, 0.5100, 0.5175, 0.4939, 0.5239, 0.5131]

ff_resnextonly_lr001_notransformed15 = [0.6147, 0.7191, 0.7774, 0.8136, 0.8242, 0.8405, 0.8656, 0.8807, 0.9043, 0.9177, 0.9253, 0.9410, 0.9425, 0.9547, 0.9634]
ff_resnextlstm_lr001_notransformed15 = [0.4936, 0.4943, 0.5091, 0.4985, 0.4973, 0.5170, 0.5021, 0.4985, 0.5043, 0.4900, 0.5046, 0.4973, 0.4931, 0.4976, 0.4990]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 16))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=ff_resnextonly_lr00001_transformed15, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr00001_transformed15, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=ff_resnextonly_lr00001_notransformed15, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr00001_notransformed15, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=ff_resnextonly_lr001_transformed15, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr001_transformed15, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=ff_resnextonly_lr001_notransformed15, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr001_notransformed15, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Accuracy 15 Epochs for FaceForensics++ Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loss

# %%
loss_ff_resnextonly_lr00001_transformed15 = [0.6350, 0.5454, 0.4646, 0.4040, 0.3402, 0.3018, 0.2806, 0.2410, 0.2042, 0.1672, 0.1368, 0.1095, 0.0987, 0.0946, 0.0801]
loss_ff_resnextlstm_lr00001_transformed15 = [0.5884, 0.4806, 0.4279, 0.3666, 0.3108, 0.2756, 0.2554, 0.2154, 0.1893, 0.1726, 0.1474, 0.1447, 0.1064, 0.0954, 0.0857]

loss_ff_resnextonly_lr00001_notransformed15 = [0.4801, 0.3386, 0.2361, 0.1755, 0.1122, 0.0820, 0.0680, 0.0555, 0.0457, 0.0504, 0.0428, 0.0338, 0.0368, 0.0326, 0.0329]
loss_ff_resnextlstm_lr00001_notransformed15 = [0.4676, 0.2749, 0.2093, 0.1449, 0.1011, 0.0828, 0.0603, 0.0520, 0.0373, 0.0449, 0.0325, 0.0403, 0.0312, 0.0206, 0.0264]

loss_ff_resnextonly_lr001_transformed15 = [0.9093, 0.5766, 0.5268, 0.4516, 0.3939, 0.3512, 0.2975, 0.2700, 0.2178, 0.1820, 0.1503, 0.1279, 0.1140, 0.1061, 0.0901]
loss_ff_resnextlstm_lr001_transformed15 = [0.7500, 0.7495, 0.7406, 0.7352, 0.7518, 0.7458, 0.7487, 0.7381, 0.7507, 0.7359, 0.7450, 0.7416, 0.7502, 0.7299, 0.7327]

loss_ff_resnextonly_lr001_notransformed15 = [0.8117, 0.5609, 0.4667, 0.4044, 0.3787, 0.3502, 0.3050, 0.2835, 0.2377, 0.2069, 0.1840, 0.1528, 0.1551, 0.1164, 0.0968]
loss_ff_resnextlstm_lr001_notransformed15 = [0.7496, 0.7560, 0.7615, 0.7585, 0.7507, 0.7294, 0.7959, 0.7641, 0.7401, 0.7578, 0.7361, 0.7742, 0.7513, 0.7670, 0.7753]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 16))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr00001_transformed15, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr00001_transformed15, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr00001_notransformed15, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr00001_notransformed15, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr001_transformed15, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr001_transformed15, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr001_notransformed15, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr001_notransformed15, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Loss 15 Epochs for FaceForensics++ Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# # 20 Epoch

# %% [markdown]
# ## Accuracy

# %%
ff_resnextonly_lr00001_transformed20 = [0.6569, 0.7226, 0.7648, 0.8081, 0.8244, 0.8517, 0.8698, 0.8886, 0.9057, 0.9074, 0.9197, 0.9413, 0.9518, 0.9636, 0.9647, 0.9725, 0.9743, 0.9778, 0.9792, 0.9823]
ff_resnextlstm_lr00001_transformed20 = [0.6682, 0.7685, 0.8130, 0.8410, 0.8614, 0.8726, 0.8864, 0.9065, 0.9175, 0.9376, 0.9485, 0.9547, 0.9576, 0.9714, 0.9765, 0.9799, 0.9790, 0.9801, 0.9819, 0.9866]

ff_resnextonly_lr00001_notransformed20 = [0.7370, 0.8385, 0.8865, 0.9179, 0.9480, 0.9606, 0.9752, 0.9798, 0.9826, 0.9877, 0.9832, 0.9800, 0.9889, 0.9896, 0.9916, 0.9979, 0.9909, 0.9940, 0.9881, 0.9931]
ff_resnextlstm_lr00001_notransformed20 = [0.7589, 0.8856, 0.9280, 0.9486, 0.9696, 0.9781, 0.9850, 0.9794, 0.9867, 0.9871, 0.9912, 0.9899, 0.9888, 0.9913, 0.9913, 0.9961, 0.9899, 0.9947, 0.9934, 0.9968]

ff_resnextonly_lr001_transformed20 = [0.6139, 0.7238, 0.7663, 0.8005, 0.8237, 0.8450, 0.8658, 0.8847, 0.9016, 0.9177, 0.9366, 0.9378, 0.9498, 0.9608, 0.9635, 0.9685, 0.9759, 0.9779, 0.9814, 0.9814]
ff_resnextlstm_lr001_transformed20 = [0.4921, 0.4957, 0.4972, 0.5015, 0.4952, 0.4946, 0.5073, 0.4986, 0.4953, 0.4990, 0.5011, 0.4994, 0.5050, 0.4999, 0.4990, 0.4980, 0.5019, 0.5024, 0.5117, 0.5078]

ff_resnextonly_lr001_notransformed20 = [0.6355, 0.7541, 0.7902, 0.8317, 0.8652, 0.8859, 0.9151, 0.9294, 0.9470, 0.9528, 0.9554, 0.9665, 0.9623, 0.9735, 0.9743, 0.9748, 0.9722, 0.9832, 0.9822, 0.9804]
ff_resnextlstm_lr001_notransformed20 = [0.5031, 0.5013, 0.5069, 0.5049, 0.5102, 0.5013, 0.4979, 0.5027, 0.4999, 0.4931, 0.4968, 0.4987, 0.5032, 0.4943, 0.4987, 0.5083, 0.4931, 0.4912, 0.4926, 0.4973]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 21))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=ff_resnextonly_lr00001_transformed20, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr00001_transformed20, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=ff_resnextonly_lr00001_notransformed20, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr00001_notransformed20, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=ff_resnextonly_lr001_transformed20, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr001_transformed20, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=ff_resnextonly_lr001_notransformed20, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=ff_resnextlstm_lr001_notransformed20, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Accuracy 20 Epochs for FaceForensics++ Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loss

# %%
loss_ff_resnextonly_lr00001_transformed20 = [0.6342, 0.5536, 0.4880, 0.4285, 0.3865, 0.3360, 0.2943, 0.2567, 0.2215, 0.2129, 0.1929, 0.1518, 0.1231, 0.0966, 0.0980, 0.0735, 0.0690, 0.0597, 0.0549, 0.0493]
loss_ff_resnextlstm_lr00001_transformed20 = [0.6036, 0.4926, 0.4195, 0.3564, 0.3063, 0.2762, 0.2483, 0.2136, 0.1878, 0.1537, 0.1303, 0.1143, 0.1125, 0.0781, 0.0712, 0.0566, 0.0593, 0.0572, 0.0512, 0.0378]

loss_ff_resnextonly_lr00001_notransformed20 = [0.5141, 0.3586, 0.2728, 0.1957, 0.1370, 0.1014, 0.0701, 0.0572, 0.0525, 0.0333, 0.0452, 0.0612, 0.0318, 0.0297, 0.0243, 0.0083, 0.0288, 0.0217, 0.0360, 0.0175]
loss_ff_resnextlstm_lr00001_notransformed20 = [0.4770, 0.2750, 0.1873, 0.1313, 0.0817, 0.0591, 0.0464, 0.0580, 0.0408, 0.0410, 0.0268, 0.0281, 0.0329, 0.0248, 0.0271, 0.0130, 0.0282, 0.0164, 0.0175, 0.0109]

loss_ff_resnextonly_lr001_transformed20 = [0.7912, 0.5546, 0.4989, 0.4420, 0.3976, 0.3549, 0.3078, 0.2707, 0.2353, 0.1973, 0.1679, 0.1595, 0.1318, 0.1029, 0.0942, 0.0862, 0.0681, 0.0646, 0.0544, 0.0535]
loss_ff_resnextlstm_lr001_transformed20 = [0.7622, 0.7897, 0.7453, 0.7594, 0.7625, 0.7606, 0.7511, 0.7673, 0.7798, 0.7325, 0.7467, 0.7448, 0.7724, 0.7562, 0.7642, 0.7876, 0.7721, 0.7616, 0.7928, 0.7366]

loss_ff_resnextonly_lr001_notransformed20 = [0.7595, 0.5131, 0.4445, 0.3703, 0.3230, 0.2690, 0.2185, 0.1770, 0.1418, 0.1289, 0.1220, 0.0953, 0.0979, 0.0725, 0.0738, 0.0651, 0.0748, 0.0517, 0.0547, 0.0591]
loss_ff_resnextlstm_lr001_notransformed20 = [0.7912, 0.7716, 0.8291, 0.7539, 0.7653, 0.7706, 0.7556, 0.7409, 0.7908, 0.7661, 0.7849, 0.7711, 0.7860, 0.7574, 0.7729, 0.7682, 0.7751, 0.7842, 0.7771, 0.7825]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid", context="talk")

# Define epochs
epochs = list(range(1, 21))

# Prepare the plot
plt.figure(figsize=(14, 8))

# Define colors for clarity
palette = sns.color_palette("husl", 8)  # Generate 8 distinct colors

# Plot each dataset
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr00001_transformed20, label="ResNext Only, LR=0.0001 (Transformed Data Added)", marker='o', linestyle='-', color=palette[0])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr00001_transformed20, label="ResNext+LSTM, LR=0.0001 (Transformed Data Added)", marker='s', linestyle='--', color=palette[1])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr00001_notransformed20, label="ResNext Only, LR=0.0001 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[2])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr00001_notransformed20, label="ResNext+LSTM, LR=0.0001 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[3])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr001_transformed20, label="ResNext Only, LR=0.01 (Transformed Data Added)", marker='o', linestyle='-', color=palette[4])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr001_transformed20, label="ResNext+LSTM, LR=0.01 (Transformed Data Added)", marker='s', linestyle='--', color=palette[5])
sns.lineplot(x=epochs, y=loss_ff_resnextonly_lr001_notransformed20, label="ResNext Only, LR=0.01 (No Transformed Data Added)", marker='o', linestyle='-', color=palette[6])
sns.lineplot(x=epochs, y=loss_ff_resnextlstm_lr001_notransformed20, label="ResNext+LSTM, LR=0.01 (No Transformed Data Added)", marker='s', linestyle='--', color=palette[7])

# Add labels and title
plt.title("Loss 20 Epochs for FaceForensics++ Configurations", fontsize=16, weight='bold')
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)

# Customize legend
plt.legend(title="Configurations", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, title_fontsize=14)

# Add grid and style adjustments
plt.tight_layout()
plt.show()
